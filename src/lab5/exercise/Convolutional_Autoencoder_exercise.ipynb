# %%
import matplotlib.pyplot as plt # plotting library
import numpy as np # this module is useful to work with numerical arrays
import pandas as pd 
import random 
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader,random_split
from torch import nn
import torch.nn.functional as F
import torch.optim as optim

data_dir = 'dataset'

train_dataset = torchvision.datasets.MNIST(data_dir, train=True, download=True)
test_dataset  = torchvision.datasets.MNIST(data_dir, train=False, download=True)

train_transform = transforms.Compose([
transforms.ToTensor(),
])

test_transform = transforms.Compose([
transforms.ToTensor(),
])

train_dataset.transform = train_transform
test_dataset.transform = test_transform

m=len(train_dataset)

train_data, val_data = random_split(train_dataset, [int(m-m*0.2), int(m*0.2)])
batch_size=256

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,shuffle=True)

# %%
class Encoder(nn.Module):

  def __init__(self, encoded_space_dim):
    super().__init__()

    # conv2d -> input_channel, output_channel, kernel_size
    self.encoder_cnn = nn.Sequential(
        nn.Conv2d(1, 8, 3, stride=2, padding=1),
        nn.ReLU(True),
        nn.Conv2d(8, 16, 3, stride=2, padding=1),
        nn.BatchNorm2d(16),
        nn.ReLU(True),
        nn.Conv2d(16, 32, 3, stride=2, padding=0),
        nn.ReLU(True)
    )

    # start dim tells us from which dimension to start
    # flattening
    self.flatten = nn.Flatten(start_dim=1)

    self.encoder_lin = nn.Sequential(
        nn.Linear(3*3*32,128),
        nn.ReLU(True),
        nn.Linear(128, encoded_space_dim)
    )

  def forward(self, x):
    x = self.encoder_cnn(x)
    x = self.flatten(x)
    x = self.encoder_lin(x)
    return x

# %%
encoder = Encoder(4)

# %%
encoder
# Out:
# Encoder(
#   (encoder_cnn): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU(inplace=True)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#     (6): ReLU(inplace=True)
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (encoder_lin): Sequential(
#     (0): Linear(in_features=288, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=4, bias=True)
#   )
# )

# %%
class Decoder(nn.Module):

  def __init__(self, encoded_space_dim):
    super().__init__()
    self.decoder_lin = nn.Sequential(
        nn.Linear(encoded_space_dim, 128),
        nn.ReLU(True),
        nn.Linear(128, 3*3*32),
        nn.ReLU(True)
    )

    self.unflatten = nn.Unflatten(dim=1,
                                  unflattened_size=(32,3,3))
    
    # ConvTranspose2d -> input_channels, output_channels, kernel_size
    # output_padding -> controls the output padding
    self.decoder_conv = nn.Sequential(
        nn.ConvTranspose2d(32, 16, 3, stride=2, output_padding=0),
        nn.BatchNorm2d(16),
        nn.ReLU(True),
        nn.ConvTranspose2d(16, 8, 3, stride=2, padding=1,
                           output_padding=1),
        nn.BatchNorm2d(8),
        nn.ReLU(True),
        nn.ConvTranspose2d(8, 1, 3, stride=2, padding=1,
                           output_padding=1)
    )

  def forward(self, x):
    x = self.decoder_lin(x)
    x = self.unflatten(x)
    x = self.decoder_conv(x)
    x = torch.sigmoid(x)
    return x

# %%
decoder = Decoder(4)

# %%
decoder
# Out:
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=288, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(32, 3, 3))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   )
# )

# %%
### Define the loss function
loss_fn = torch.nn.MSELoss()

### Define an optimizer (both for the encoder and the decoder!)
lr= 0.001

### Set the random seed for reproducible results
torch.manual_seed(0)

### Initialize the two networks
d = 4

#model = Autoencoder(encoded_space_dim=encoded_space_dim)
encoder = Encoder(encoded_space_dim=d)
decoder = Decoder(encoded_space_dim=d)
params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]

optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-05)

# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Selected device: {device}')

# Move both the encoder and the decoder to the selected device
encoder.to(device)
decoder.to(device)
# Out:
# Selected device: cuda
# Decoder(
#   (decoder_lin): Sequential(
#     (0): Linear(in_features=4, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=288, bias=True)
#     (3): ReLU(inplace=True)
#   )
#   (unflatten): Unflatten(dim=1, unflattened_size=(32, 3, 3))
#   (decoder_conv): Sequential(
#     (0): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(16, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (4): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(8, 1, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   )
# )

# %%
def train_epoch(encoder, decoder, device, dataloader, loss_fn, optimizer):
  encoder.train()
  decoder.train()

  train_loss = []

  for image_batch, _ in dataloader: # ignore the labels
    image_batch = image_batch.to(device)

    encoded_data = encoder(image_batch)
    decoded_data = decoder(encoded_data)

    loss = loss_fn(decoded_data, image_batch)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    print('\t partial train loss (single batch): %f ' % (loss.data))
    train_loss.append(loss.detach().cpu().numpy())

  return np.mean(train_loss)

# %%
def test_epoch(encoder, decoder, device, dataloader, loss_fn):
  encoder.eval()
  decoder.eval()

  with torch.no_grad(): # no need to track the gradients
    conc_out = []
    conc_label = []

    for image_batch, _ in dataloader:
      image_batch = image_batch.to(device)

      encoded_data = encoder(image_batch)

      decoded_data = decoder(encoded_data)

      conc_out.append(decoded_data.cpu())
      conc_label.append(image_batch.cpu())

    # create a single tensor with all the values in the lists
    conc_out = torch.cat(conc_out)
    conc_label = torch.cat(conc_label)

    # evaluate global loss
    val_loss = loss_fn(conc_out, conc_label)

  return val_loss.data

# %%
num_epochs = 30
dict_loss = {
    'train_loss':[],
    'val_loss':[]
}

for epoch in range(num_epochs):
  train_loss = train_epoch(encoder, decoder, device,
                           train_loader, loss_fn, optim)
  
  val_loss = test_epoch(encoder, decoder, device,
                        val_loader, loss_fn)
  

  print('\n EPOCH {}/{} \t train loss {} \t val loss {}'.format(epoch+1,
                                                                num_epochs,
                                                                train_loss,
                                                                val_loss))
  

  dict_loss['train_loss'].append(train_loss)
  dict_loss['val_loss'].append(val_loss)
# Out:
# Streaming output truncated to the last 5000 lines.
# 	 partial train loss (single batch): 0.035508
# 	 partial train loss (single batch): 0.035728
# 	 partial train loss (single batch): 0.035138
# 	 partial train loss (single batch): 0.034836
# 	 partial train loss (single batch): 0.034859
# 	 partial train loss (single batch): 0.034414
# 	 partial train loss (single batch): 0.035046
# 	 partial train loss (single batch): 0.036565
# 	 partial train loss (single batch): 0.032647
# 	 partial train loss (single batch): 0.035048
# 	 partial train loss (single batch): 0.032931
# 	 partial train loss (single batch): 0.033641
# 	 partial train loss (single batch): 0.033423
# 	 partial train loss (single batch): 0.034425
# 	 partial train loss (single batch): 0.033961
# 	 partial train loss (single batch): 0.033451
# 	 partial train loss (single batch): 0.033266
# 	 partial train loss (single batch): 0.034562
# 	 partial train loss (single batch): 0.034763
# 	 partial train loss (single batch): 0.034863
# 	 partial train loss (single batch): 0.033482
# 	 partial train loss (single batch): 0.035125
# 	 partial train loss (single batch): 0.034303
# 	 partial train loss (single batch): 0.034370
# 	 partial train loss (single batch): 0.033416
# 	 partial train loss (single batch): 0.035369
# 	 partial train loss (single batch): 0.034043
# 	 partial train loss (single batch): 0.034685
# 	 partial train loss (single batch): 0.034448
# 	 partial train loss (single batch): 0.032873
# 	 partial train loss (single batch): 0.033346
# 	 partial train loss (single batch): 0.035127
# 	 partial train loss (single batch): 0.033874
# 	 partial train loss (single batch): 0.034031
# 	 partial train loss (single batch): 0.033028
# 	 partial train loss (single batch): 0.033969
# 	 partial train loss (single batch): 0.034413
# 	 partial train loss (single batch): 0.033895
# 	 partial train loss (single batch): 0.033394
# 	 partial train loss (single batch): 0.034133
# 	 partial train loss (single batch): 0.033372
# 	 partial train loss (single batch): 0.033253
# 	 partial train loss (single batch): 0.034183
# 	 partial train loss (single batch): 0.034126
# 	 partial train loss (single batch): 0.034159
# 	 partial train loss (single batch): 0.033910
# 	 partial train loss (single batch): 0.034255
# 	 partial train loss (single batch): 0.033265
# 	 partial train loss (single batch): 0.032036
# 	 partial train loss (single batch): 0.034034
# 	 partial train loss (single batch): 0.034512
# 	 partial train loss (single batch): 0.032605
# 	 partial train loss (single batch): 0.033301
# 	 partial train loss (single batch): 0.033266
# 	 partial train loss (single batch): 0.031209
# 	 partial train loss (single batch): 0.032662
# 	 partial train loss (single batch): 0.033386
# 	 partial train loss (single batch): 0.034725
#
#  EPOCH 4/30 	 train loss 0.0354686863720417 	 val loss 0.03361266478896141
# 	 partial train loss (single batch): 0.033774
# 	 partial train loss (single batch): 0.034253
# 	 partial train loss (single batch): 0.035138
# 	 partial train loss (single batch): 0.032732
# 	 partial train loss (single batch): 0.032933
# 	 partial train loss (single batch): 0.033187
# 	 partial train loss (single batch): 0.034278
# 	 partial train loss (single batch): 0.034018
# 	 partial train loss (single batch): 0.031817
# 	 partial train loss (single batch): 0.035848
# 	 partial train loss (single batch): 0.032442
# 	 partial train loss (single batch): 0.032771
# 	 partial train loss (single batch): 0.033034
# 	 partial train loss (single batch): 0.034043
# 	 partial train loss (single batch): 0.033437
# 	 partial train loss (single batch): 0.034698
# 	 partial train loss (single batch): 0.033172
# 	 partial train loss (single batch): 0.033032
# 	 partial train loss (single batch): 0.033011
# 	 partial train loss (single batch): 0.034356
# 	 partial train loss (single batch): 0.034386
# 	 partial train loss (single batch): 0.034482
# 	 partial train loss (single batch): 0.033582
# 	 partial train loss (single batch): 0.033403
# 	 partial train loss (single batch): 0.032685
# 	 partial train loss (single batch): 0.032862
# 	 partial train loss (single batch): 0.034075
# 	 partial train loss (single batch): 0.032293
# 	 partial train loss (single batch): 0.032499
# 	 partial train loss (single batch): 0.033703
# 	 partial train loss (single batch): 0.032418
# 	 partial train loss (single batch): 0.032251
# 	 partial train loss (single batch): 0.034547
# 	 partial train loss (single batch): 0.030909
# 	 partial train loss (single batch): 0.033177
# 	 partial train loss (single batch): 0.035146
# 	 partial train loss (single batch): 0.032527
# 	 partial train loss (single batch): 0.033715
# 	 partial train loss (single batch): 0.032765
# 	 partial train loss (single batch): 0.031908
# 	 partial train loss (single batch): 0.031410
# 	 partial train loss (single batch): 0.033800
# 	 partial train loss (single batch): 0.034382
# 	 partial train loss (single batch): 0.032556
# 	 partial train loss (single batch): 0.032207
# 	 partial train loss (single batch): 0.032795
# 	 partial train loss (single batch): 0.033518
# 	 partial train loss (single batch): 0.033440
# 	 partial train loss (single batch): 0.032304
# 	 partial train loss (single batch): 0.032689
# 	 partial train loss (single batch): 0.033859
# 	 partial train loss (single batch): 0.031734
# 	 partial train loss (single batch): 0.032314
# 	 partial train loss (single batch): 0.033353
# 	 partial train loss (single batch): 0.033404
# 	 partial train loss (single batch): 0.032192
# 	 partial train loss (single batch): 0.031465
# 	 partial train loss (single batch): 0.032445
# 	 partial train loss (single batch): 0.032249
# 	 partial train loss (single batch): 0.032416
# 	 partial train loss (single batch): 0.031795
# 	 partial train loss (single batch): 0.032321
# 	 partial train loss (single batch): 0.032539
# 	 partial train loss (single batch): 0.030238
# 	 partial train loss (single batch): 0.033405
# 	 partial train loss (single batch): 0.033034
# 	 partial train loss (single batch): 0.032844
# 	 partial train loss (single batch): 0.032268
# 	 partial train loss (single batch): 0.029531
# 	 partial train loss (single batch): 0.033200
# 	 partial train loss (single batch): 0.033805
# 	 partial train loss (single batch): 0.033883
# 	 partial train loss (single batch): 0.031912
# 	 partial train loss (single batch): 0.032194
# 	 partial train loss (single batch): 0.032040
# 	 partial train loss (single batch): 0.034255
# 	 partial train loss (single batch): 0.031782
# 	 partial train loss (single batch): 0.032747
# 	 partial train loss (single batch): 0.033118
# 	 partial train loss (single batch): 0.031637
# 	 partial train loss (single batch): 0.032338
# 	 partial train loss (single batch): 0.032922
# 	 partial train loss (single batch): 0.033412
# 	 partial train loss (single batch): 0.030707
# 	 partial train loss (single batch): 0.032558
# 	 partial train loss (single batch): 0.032824
# 	 partial train loss (single batch): 0.032435
# 	 partial train loss (single batch): 0.032039
# 	 partial train loss (single batch): 0.031818
# 	 partial train loss (single batch): 0.034147
# 	 partial train loss (single batch): 0.032266
# 	 partial train loss (single batch): 0.030983
# 	 partial train loss (single batch): 0.031579
# 	 partial train loss (single batch): 0.031256
# 	 partial train loss (single batch): 0.030748
# 	 partial train loss (single batch): 0.031860
# 	 partial train loss (single batch): 0.031216
# 	 partial train loss (single batch): 0.030701
# 	 partial train loss (single batch): 0.032880
# 	 partial train loss (single batch): 0.033195
# 	 partial train loss (single batch): 0.032521
# 	 partial train loss (single batch): 0.030418
# 	 partial train loss (single batch): 0.032058
# 	 partial train loss (single batch): 0.032599
# 	 partial train loss (single batch): 0.031942
# 	 partial train loss (single batch): 0.030308
# 	 partial train loss (single batch): 0.032996
# 	 partial train loss (single batch): 0.032128
# 	 partial train loss (single batch): 0.030443
# 	 partial train loss (single batch): 0.032043
# 	 partial train loss (single batch): 0.032039
# 	 partial train loss (single batch): 0.031238
# 	 partial train loss (single batch): 0.032654
# 	 partial train loss (single batch): 0.030749
# 	 partial train loss (single batch): 0.031437
# 	 partial train loss (single batch): 0.031222
# 	 partial train loss (single batch): 0.032654
# 	 partial train loss (single batch): 0.032293
# 	 partial train loss (single batch): 0.030175
# 	 partial train loss (single batch): 0.032188
# 	 partial train loss (single batch): 0.031964
# 	 partial train loss (single batch): 0.031751
# 	 partial train loss (single batch): 0.032281
# 	 partial train loss (single batch): 0.031041
# 	 partial train loss (single batch): 0.033064
# 	 partial train loss (single batch): 0.030394
# 	 partial train loss (single batch): 0.030738
# 	 partial train loss (single batch): 0.030962
# 	 partial train loss (single batch): 0.031668
# 	 partial train loss (single batch): 0.032193
# 	 partial train loss (single batch): 0.032741
# 	 partial train loss (single batch): 0.032995
# 	 partial train loss (single batch): 0.032436
# 	 partial train loss (single batch): 0.032351
# 	 partial train loss (single batch): 0.032323
# 	 partial train loss (single batch): 0.031542
# 	 partial train loss (single batch): 0.032541
# 	 partial train loss (single batch): 0.034306
# 	 partial train loss (single batch): 0.029809
# 	 partial train loss (single batch): 0.032558
# 	 partial train loss (single batch): 0.030349
# 	 partial train loss (single batch): 0.031081
# 	 partial train loss (single batch): 0.030902
# 	 partial train loss (single batch): 0.031597
# 	 partial train loss (single batch): 0.031302
# 	 partial train loss (single batch): 0.030896
# 	 partial train loss (single batch): 0.030430
# 	 partial train loss (single batch): 0.032289
# 	 partial train loss (single batch): 0.032281
# 	 partial train loss (single batch): 0.032478
# 	 partial train loss (single batch): 0.030930
# 	 partial train loss (single batch): 0.032432
# 	 partial train loss (single batch): 0.032028
# 	 partial train loss (single batch): 0.031903
# 	 partial train loss (single batch): 0.031070
# 	 partial train loss (single batch): 0.032964
# 	 partial train loss (single batch): 0.032005
# 	 partial train loss (single batch): 0.032410
# 	 partial train loss (single batch): 0.031799
# 	 partial train loss (single batch): 0.030669
# 	 partial train loss (single batch): 0.031288
# 	 partial train loss (single batch): 0.032765
# 	 partial train loss (single batch): 0.031064
# 	 partial train loss (single batch): 0.031880
# 	 partial train loss (single batch): 0.030222
# 	 partial train loss (single batch): 0.031592
# 	 partial train loss (single batch): 0.032007
# 	 partial train loss (single batch): 0.031751
# 	 partial train loss (single batch): 0.030787
# 	 partial train loss (single batch): 0.031775
# 	 partial train loss (single batch): 0.031190
# 	 partial train loss (single batch): 0.030878
# 	 partial train loss (single batch): 0.031866
# 	 partial train loss (single batch): 0.031430
# 	 partial train loss (single batch): 0.031993
# 	 partial train loss (single batch): 0.031775
# 	 partial train loss (single batch): 0.032058
# 	 partial train loss (single batch): 0.031111
# 	 partial train loss (single batch): 0.030064
# 	 partial train loss (single batch): 0.031957
# 	 partial train loss (single batch): 0.032589
# 	 partial train loss (single batch): 0.030568
# 	 partial train loss (single batch): 0.031322
# 	 partial train loss (single batch): 0.031201
# 	 partial train loss (single batch): 0.029212
# 	 partial train loss (single batch): 0.030472
# 	 partial train loss (single batch): 0.031590
# 	 partial train loss (single batch): 0.032216
#
#  EPOCH 5/30 	 train loss 0.0322577990591526 	 val loss 0.03147594630718231
# 	 partial train loss (single batch): 0.031695
# 	 partial train loss (single batch): 0.032150
# 	 partial train loss (single batch): 0.033006
# 	 partial train loss (single batch): 0.030945
# 	 partial train loss (single batch): 0.030783
# 	 partial train loss (single batch): 0.031205
# 	 partial train loss (single batch): 0.032481
# 	 partial train loss (single batch): 0.031934
# 	 partial train loss (single batch): 0.029894
# 	 partial train loss (single batch): 0.033933
# 	 partial train loss (single batch): 0.030773
# 	 partial train loss (single batch): 0.030887
# 	 partial train loss (single batch): 0.031093
# 	 partial train loss (single batch): 0.031957
# 	 partial train loss (single batch): 0.031236
# 	 partial train loss (single batch): 0.032539
# 	 partial train loss (single batch): 0.031297
# 	 partial train loss (single batch): 0.031059
# 	 partial train loss (single batch): 0.031160
# 	 partial train loss (single batch): 0.032533
# 	 partial train loss (single batch): 0.032477
# 	 partial train loss (single batch): 0.032347
# 	 partial train loss (single batch): 0.031460
# 	 partial train loss (single batch): 0.031585
# 	 partial train loss (single batch): 0.031032
# 	 partial train loss (single batch): 0.031192
# 	 partial train loss (single batch): 0.032402
# 	 partial train loss (single batch): 0.030411
# 	 partial train loss (single batch): 0.030529
# 	 partial train loss (single batch): 0.031439
# 	 partial train loss (single batch): 0.030462
# 	 partial train loss (single batch): 0.030467
# 	 partial train loss (single batch): 0.032525
# 	 partial train loss (single batch): 0.028746
# 	 partial train loss (single batch): 0.031094
# 	 partial train loss (single batch): 0.032930
# 	 partial train loss (single batch): 0.030701
# 	 partial train loss (single batch): 0.031751
# 	 partial train loss (single batch): 0.030904
# 	 partial train loss (single batch): 0.029757
# 	 partial train loss (single batch): 0.029602
# 	 partial train loss (single batch): 0.031755
# 	 partial train loss (single batch): 0.032680
# 	 partial train loss (single batch): 0.030534
# 	 partial train loss (single batch): 0.030382
# 	 partial train loss (single batch): 0.030630
# 	 partial train loss (single batch): 0.031710
# 	 partial train loss (single batch): 0.031346
# 	 partial train loss (single batch): 0.030595
# 	 partial train loss (single batch): 0.030868
# 	 partial train loss (single batch): 0.032013
# 	 partial train loss (single batch): 0.030115
# 	 partial train loss (single batch): 0.030495
# 	 partial train loss (single batch): 0.031649
# 	 partial train loss (single batch): 0.031556
# 	 partial train loss (single batch): 0.030358
# 	 partial train loss (single batch): 0.029493
# 	 partial train loss (single batch): 0.030410
# 	 partial train loss (single batch): 0.030388
# 	 partial train loss (single batch): 0.030778
# 	 partial train loss (single batch): 0.030047
# 	 partial train loss (single batch): 0.030525
# 	 partial train loss (single batch): 0.030871
# 	 partial train loss (single batch): 0.028450
# 	 partial train loss (single batch): 0.031915
# 	 partial train loss (single batch): 0.031305
# 	 partial train loss (single batch): 0.031458
# 	 partial train loss (single batch): 0.030582
# 	 partial train loss (single batch): 0.027842
# 	 partial train loss (single batch): 0.031649
# 	 partial train loss (single batch): 0.032191
# 	 partial train loss (single batch): 0.032244
# 	 partial train loss (single batch): 0.030488
# 	 partial train loss (single batch): 0.030718
# 	 partial train loss (single batch): 0.030444
# 	 partial train loss (single batch): 0.032962
# 	 partial train loss (single batch): 0.030092
# 	 partial train loss (single batch): 0.031059
# 	 partial train loss (single batch): 0.031489
# 	 partial train loss (single batch): 0.030073
# 	 partial train loss (single batch): 0.030817
# 	 partial train loss (single batch): 0.031006
# 	 partial train loss (single batch): 0.031824
# 	 partial train loss (single batch): 0.029303
# 	 partial train loss (single batch): 0.030847
# 	 partial train loss (single batch): 0.031206
# 	 partial train loss (single batch): 0.030803
# 	 partial train loss (single batch): 0.030647
# 	 partial train loss (single batch): 0.030050
# 	 partial train loss (single batch): 0.032557
# 	 partial train loss (single batch): 0.030702
# 	 partial train loss (single batch): 0.029391
# 	 partial train loss (single batch): 0.030075
# 	 partial train loss (single batch): 0.029466
# 	 partial train loss (single batch): 0.029281
# 	 partial train loss (single batch): 0.030287
# 	 partial train loss (single batch): 0.029758
# 	 partial train loss (single batch): 0.029460
# 	 partial train loss (single batch): 0.031119
# 	 partial train loss (single batch): 0.031946
# 	 partial train loss (single batch): 0.031097
# 	 partial train loss (single batch): 0.028721
# 	 partial train loss (single batch): 0.030539
# 	 partial train loss (single batch): 0.031120
# 	 partial train loss (single batch): 0.030509
# 	 partial train loss (single batch): 0.028667
# 	 partial train loss (single batch): 0.031649
# 	 partial train loss (single batch): 0.030951
# 	 partial train loss (single batch): 0.028892
# 	 partial train loss (single batch): 0.030457
# 	 partial train loss (single batch): 0.030513
# 	 partial train loss (single batch): 0.029660
# 	 partial train loss (single batch): 0.031154
# 	 partial train loss (single batch): 0.029286
# 	 partial train loss (single batch): 0.029900
# 	 partial train loss (single batch): 0.029587
# 	 partial train loss (single batch): 0.031165
# 	 partial train loss (single batch): 0.030732
# 	 partial train loss (single batch): 0.028845
# 	 partial train loss (single batch): 0.030623
# 	 partial train loss (single batch): 0.030738
# 	 partial train loss (single batch): 0.030333
# 	 partial train loss (single batch): 0.030972
# 	 partial train loss (single batch): 0.029676
# 	 partial train loss (single batch): 0.031499
# 	 partial train loss (single batch): 0.028938
# 	 partial train loss (single batch): 0.029285
# 	 partial train loss (single batch): 0.029585
# 	 partial train loss (single batch): 0.030235
# 	 partial train loss (single batch): 0.030883
# 	 partial train loss (single batch): 0.031385
# 	 partial train loss (single batch): 0.031608
# 	 partial train loss (single batch): 0.031063
# 	 partial train loss (single batch): 0.030891
# 	 partial train loss (single batch): 0.031099
# 	 partial train loss (single batch): 0.030122
# 	 partial train loss (single batch): 0.031120
# 	 partial train loss (single batch): 0.033001
# 	 partial train loss (single batch): 0.028282
# 	 partial train loss (single batch): 0.031242
# 	 partial train loss (single batch): 0.029040
# 	 partial train loss (single batch): 0.029690
# 	 partial train loss (single batch): 0.029540
# 	 partial train loss (single batch): 0.030199
# 	 partial train loss (single batch): 0.030038
# 	 partial train loss (single batch): 0.029637
# 	 partial train loss (single batch): 0.029167
# 	 partial train loss (single batch): 0.031134
# 	 partial train loss (single batch): 0.031078
# 	 partial train loss (single batch): 0.031196
# 	 partial train loss (single batch): 0.029593
# 	 partial train loss (single batch): 0.031000
# 	 partial train loss (single batch): 0.030531
# 	 partial train loss (single batch): 0.030467
# 	 partial train loss (single batch): 0.029677
# 	 partial train loss (single batch): 0.031527
# 	 partial train loss (single batch): 0.030855
# 	 partial train loss (single batch): 0.031052
# 	 partial train loss (single batch): 0.030386
# 	 partial train loss (single batch): 0.029249
# 	 partial train loss (single batch): 0.029858
# 	 partial train loss (single batch): 0.031522
# 	 partial train loss (single batch): 0.029620
# 	 partial train loss (single batch): 0.030617
# 	 partial train loss (single batch): 0.028858
# 	 partial train loss (single batch): 0.030345
# 	 partial train loss (single batch): 0.030556
# 	 partial train loss (single batch): 0.030743
# 	 partial train loss (single batch): 0.029741
# 	 partial train loss (single batch): 0.030476
# 	 partial train loss (single batch): 0.029973
# 	 partial train loss (single batch): 0.029559
# 	 partial train loss (single batch): 0.030530
# 	 partial train loss (single batch): 0.030112
# 	 partial train loss (single batch): 0.030684
# 	 partial train loss (single batch): 0.030473
# 	 partial train loss (single batch): 0.031020
# 	 partial train loss (single batch): 0.030016
# 	 partial train loss (single batch): 0.028951
# 	 partial train loss (single batch): 0.030723
# 	 partial train loss (single batch): 0.031256
# 	 partial train loss (single batch): 0.029426
# 	 partial train loss (single batch): 0.030179
# 	 partial train loss (single batch): 0.030135
# 	 partial train loss (single batch): 0.027988
# 	 partial train loss (single batch): 0.029119
# 	 partial train loss (single batch): 0.030475
# 	 partial train loss (single batch): 0.030940
#
#  EPOCH 6/30 	 train loss 0.03067045845091343 	 val loss 0.030335936695337296
# 	 partial train loss (single batch): 0.030639
# 	 partial train loss (single batch): 0.030905
# 	 partial train loss (single batch): 0.031782
# 	 partial train loss (single batch): 0.029867
# 	 partial train loss (single batch): 0.029512
# 	 partial train loss (single batch): 0.029778
# 	 partial train loss (single batch): 0.031081
# 	 partial train loss (single batch): 0.030729
# 	 partial train loss (single batch): 0.028634
# 	 partial train loss (single batch): 0.032636
# 	 partial train loss (single batch): 0.029729
# 	 partial train loss (single batch): 0.029915
# 	 partial train loss (single batch): 0.029746
# 	 partial train loss (single batch): 0.030820
# 	 partial train loss (single batch): 0.030091
# 	 partial train loss (single batch): 0.031335
# 	 partial train loss (single batch): 0.029987
# 	 partial train loss (single batch): 0.029800
# 	 partial train loss (single batch): 0.029968
# 	 partial train loss (single batch): 0.031289
# 	 partial train loss (single batch): 0.031208
# 	 partial train loss (single batch): 0.031152
# 	 partial train loss (single batch): 0.030174
# 	 partial train loss (single batch): 0.030307
# 	 partial train loss (single batch): 0.029757
# 	 partial train loss (single batch): 0.030074
# 	 partial train loss (single batch): 0.031381
# 	 partial train loss (single batch): 0.029136
# 	 partial train loss (single batch): 0.029270
# 	 partial train loss (single batch): 0.030143
# 	 partial train loss (single batch): 0.029152
# 	 partial train loss (single batch): 0.029523
# 	 partial train loss (single batch): 0.031469
# 	 partial train loss (single batch): 0.027698
# 	 partial train loss (single batch): 0.030118
# 	 partial train loss (single batch): 0.031697
# 	 partial train loss (single batch): 0.029721
# 	 partial train loss (single batch): 0.030856
# 	 partial train loss (single batch): 0.029967
# 	 partial train loss (single batch): 0.028735
# 	 partial train loss (single batch): 0.028695
# 	 partial train loss (single batch): 0.030778
# 	 partial train loss (single batch): 0.031798
# 	 partial train loss (single batch): 0.029653
# 	 partial train loss (single batch): 0.029421
# 	 partial train loss (single batch): 0.029666
# 	 partial train loss (single batch): 0.030712
# 	 partial train loss (single batch): 0.030183
# 	 partial train loss (single batch): 0.029620
# 	 partial train loss (single batch): 0.029680
# 	 partial train loss (single batch): 0.030999
# 	 partial train loss (single batch): 0.029088
# 	 partial train loss (single batch): 0.029488
# 	 partial train loss (single batch): 0.030613
# 	 partial train loss (single batch): 0.030349
# 	 partial train loss (single batch): 0.029467
# 	 partial train loss (single batch): 0.028409
# 	 partial train loss (single batch): 0.029305
# 	 partial train loss (single batch): 0.029383
# 	 partial train loss (single batch): 0.029830
# 	 partial train loss (single batch): 0.029002
# 	 partial train loss (single batch): 0.029432
# 	 partial train loss (single batch): 0.029783
# 	 partial train loss (single batch): 0.027352
# 	 partial train loss (single batch): 0.030713
# 	 partial train loss (single batch): 0.030459
# 	 partial train loss (single batch): 0.030350
# 	 partial train loss (single batch): 0.029569
# 	 partial train loss (single batch): 0.026842
# 	 partial train loss (single batch): 0.030409
# 	 partial train loss (single batch): 0.031255
# 	 partial train loss (single batch): 0.031399
# 	 partial train loss (single batch): 0.029461
# 	 partial train loss (single batch): 0.029885
# 	 partial train loss (single batch): 0.029189
# 	 partial train loss (single batch): 0.032137
# 	 partial train loss (single batch): 0.029250
# 	 partial train loss (single batch): 0.029912
# 	 partial train loss (single batch): 0.030618
# 	 partial train loss (single batch): 0.029230
# 	 partial train loss (single batch): 0.029726
# 	 partial train loss (single batch): 0.030006
# 	 partial train loss (single batch): 0.030872
# 	 partial train loss (single batch): 0.028297
# 	 partial train loss (single batch): 0.029965
# 	 partial train loss (single batch): 0.030394
# 	 partial train loss (single batch): 0.029940
# 	 partial train loss (single batch): 0.029541
# 	 partial train loss (single batch): 0.029250
# 	 partial train loss (single batch): 0.031525
# 	 partial train loss (single batch): 0.029689
# 	 partial train loss (single batch): 0.028656
# 	 partial train loss (single batch): 0.029075
# 	 partial train loss (single batch): 0.028587
# 	 partial train loss (single batch): 0.028332
# 	 partial train loss (single batch): 0.029490
# 	 partial train loss (single batch): 0.028837
# 	 partial train loss (single batch): 0.028593
# 	 partial train loss (single batch): 0.030137
# 	 partial train loss (single batch): 0.031193
# 	 partial train loss (single batch): 0.030328
# 	 partial train loss (single batch): 0.027702
# 	 partial train loss (single batch): 0.029801
# 	 partial train loss (single batch): 0.030274
# 	 partial train loss (single batch): 0.029662
# 	 partial train loss (single batch): 0.027832
# 	 partial train loss (single batch): 0.030663
# 	 partial train loss (single batch): 0.030117
# 	 partial train loss (single batch): 0.027956
# 	 partial train loss (single batch): 0.029343
# 	 partial train loss (single batch): 0.029604
# 	 partial train loss (single batch): 0.028768
# 	 partial train loss (single batch): 0.030297
# 	 partial train loss (single batch): 0.028383
# 	 partial train loss (single batch): 0.028902
# 	 partial train loss (single batch): 0.028539
# 	 partial train loss (single batch): 0.030172
# 	 partial train loss (single batch): 0.029793
# 	 partial train loss (single batch): 0.027972
# 	 partial train loss (single batch): 0.029704
# 	 partial train loss (single batch): 0.030026
# 	 partial train loss (single batch): 0.029325
# 	 partial train loss (single batch): 0.030347
# 	 partial train loss (single batch): 0.028944
# 	 partial train loss (single batch): 0.030469
# 	 partial train loss (single batch): 0.028050
# 	 partial train loss (single batch): 0.028416
# 	 partial train loss (single batch): 0.028732
# 	 partial train loss (single batch): 0.029414
# 	 partial train loss (single batch): 0.030087
# 	 partial train loss (single batch): 0.030452
# 	 partial train loss (single batch): 0.030876
# 	 partial train loss (single batch): 0.030221
# 	 partial train loss (single batch): 0.029995
# 	 partial train loss (single batch): 0.030261
# 	 partial train loss (single batch): 0.029249
# 	 partial train loss (single batch): 0.030150
# 	 partial train loss (single batch): 0.032077
# 	 partial train loss (single batch): 0.027564
# 	 partial train loss (single batch): 0.030315
# 	 partial train loss (single batch): 0.028334
# 	 partial train loss (single batch): 0.029032
# 	 partial train loss (single batch): 0.028743
# 	 partial train loss (single batch): 0.029387
# 	 partial train loss (single batch): 0.029253
# 	 partial train loss (single batch): 0.028839
# 	 partial train loss (single batch): 0.028307
# 	 partial train loss (single batch): 0.030425
# 	 partial train loss (single batch): 0.030398
# 	 partial train loss (single batch): 0.030580
# 	 partial train loss (single batch): 0.028708
# 	 partial train loss (single batch): 0.030108
# 	 partial train loss (single batch): 0.029769
# 	 partial train loss (single batch): 0.029627
# 	 partial train loss (single batch): 0.028768
# 	 partial train loss (single batch): 0.030709
# 	 partial train loss (single batch): 0.030094
# 	 partial train loss (single batch): 0.030257
# 	 partial train loss (single batch): 0.029642
# 	 partial train loss (single batch): 0.028271
# 	 partial train loss (single batch): 0.028967
# 	 partial train loss (single batch): 0.030905
# 	 partial train loss (single batch): 0.028795
# 	 partial train loss (single batch): 0.029912
# 	 partial train loss (single batch): 0.028045
# 	 partial train loss (single batch): 0.029647
# 	 partial train loss (single batch): 0.029734
# 	 partial train loss (single batch): 0.030116
# 	 partial train loss (single batch): 0.029003
# 	 partial train loss (single batch): 0.029690
# 	 partial train loss (single batch): 0.029210
# 	 partial train loss (single batch): 0.028779
# 	 partial train loss (single batch): 0.029678
# 	 partial train loss (single batch): 0.029346
# 	 partial train loss (single batch): 0.029860
# 	 partial train loss (single batch): 0.029576
# 	 partial train loss (single batch): 0.030171
# 	 partial train loss (single batch): 0.029361
# 	 partial train loss (single batch): 0.028199
# 	 partial train loss (single batch): 0.029894
# 	 partial train loss (single batch): 0.030428
# 	 partial train loss (single batch): 0.028611
# 	 partial train loss (single batch): 0.029393
# 	 partial train loss (single batch): 0.029266
# 	 partial train loss (single batch): 0.027155
# 	 partial train loss (single batch): 0.028146
# 	 partial train loss (single batch): 0.029546
# 	 partial train loss (single batch): 0.030137
#
#  EPOCH 7/30 	 train loss 0.02971740998327732 	 val loss 0.02956969477236271
# 	 partial train loss (single batch): 0.029872
# 	 partial train loss (single batch): 0.030077
# 	 partial train loss (single batch): 0.031048
# 	 partial train loss (single batch): 0.029276
# 	 partial train loss (single batch): 0.028870
# 	 partial train loss (single batch): 0.028797
# 	 partial train loss (single batch): 0.030144
# 	 partial train loss (single batch): 0.030169
# 	 partial train loss (single batch): 0.027891
# 	 partial train loss (single batch): 0.031801
# 	 partial train loss (single batch): 0.029019
# 	 partial train loss (single batch): 0.029302
# 	 partial train loss (single batch): 0.028946
# 	 partial train loss (single batch): 0.030147
# 	 partial train loss (single batch): 0.029166
# 	 partial train loss (single batch): 0.030571
# 	 partial train loss (single batch): 0.029145
# 	 partial train loss (single batch): 0.028783
# 	 partial train loss (single batch): 0.029103
# 	 partial train loss (single batch): 0.030623
# 	 partial train loss (single batch): 0.030263
# 	 partial train loss (single batch): 0.030377
# 	 partial train loss (single batch): 0.029362
# 	 partial train loss (single batch): 0.029282
# 	 partial train loss (single batch): 0.028882
# 	 partial train loss (single batch): 0.029319
# 	 partial train loss (single batch): 0.030677
# 	 partial train loss (single batch): 0.028399
# 	 partial train loss (single batch): 0.028302
# 	 partial train loss (single batch): 0.029236
# 	 partial train loss (single batch): 0.028348
# 	 partial train loss (single batch): 0.028698
# 	 partial train loss (single batch): 0.030766
# 	 partial train loss (single batch): 0.027096
# 	 partial train loss (single batch): 0.029411
# 	 partial train loss (single batch): 0.031038
# 	 partial train loss (single batch): 0.028901
# 	 partial train loss (single batch): 0.030215
# 	 partial train loss (single batch): 0.029488
# 	 partial train loss (single batch): 0.027959
# 	 partial train loss (single batch): 0.028036
# 	 partial train loss (single batch): 0.030102
# 	 partial train loss (single batch): 0.031125
# 	 partial train loss (single batch): 0.029064
# 	 partial train loss (single batch): 0.028950
# 	 partial train loss (single batch): 0.028992
# 	 partial train loss (single batch): 0.030038
# 	 partial train loss (single batch): 0.029453
# 	 partial train loss (single batch): 0.028974
# 	 partial train loss (single batch): 0.028958
# 	 partial train loss (single batch): 0.030314
# 	 partial train loss (single batch): 0.028451
# 	 partial train loss (single batch): 0.028975
# 	 partial train loss (single batch): 0.029932
# 	 partial train loss (single batch): 0.029618
# 	 partial train loss (single batch): 0.028834
# 	 partial train loss (single batch): 0.027888
# 	 partial train loss (single batch): 0.028702
# 	 partial train loss (single batch): 0.028669
# 	 partial train loss (single batch): 0.029189
# 	 partial train loss (single batch): 0.028365
# 	 partial train loss (single batch): 0.028693
# 	 partial train loss (single batch): 0.029076
# 	 partial train loss (single batch): 0.026617
# 	 partial train loss (single batch): 0.029958
# 	 partial train loss (single batch): 0.029993
# 	 partial train loss (single batch): 0.029665
# 	 partial train loss (single batch): 0.028814
# 	 partial train loss (single batch): 0.026157
# 	 partial train loss (single batch): 0.029639
# 	 partial train loss (single batch): 0.030627
# 	 partial train loss (single batch): 0.030768
# 	 partial train loss (single batch): 0.028733
# 	 partial train loss (single batch): 0.029063
# 	 partial train loss (single batch): 0.028608
# 	 partial train loss (single batch): 0.031537
# 	 partial train loss (single batch): 0.028697
# 	 partial train loss (single batch): 0.029290
# 	 partial train loss (single batch): 0.029942
# 	 partial train loss (single batch): 0.028623
# 	 partial train loss (single batch): 0.029017
# 	 partial train loss (single batch): 0.029335
# 	 partial train loss (single batch): 0.030201
# 	 partial train loss (single batch): 0.027650
# 	 partial train loss (single batch): 0.029229
# 	 partial train loss (single batch): 0.029783
# 	 partial train loss (single batch): 0.029405
# 	 partial train loss (single batch): 0.028905
# 	 partial train loss (single batch): 0.028730
# 	 partial train loss (single batch): 0.030931
# 	 partial train loss (single batch): 0.029010
# 	 partial train loss (single batch): 0.028062
# 	 partial train loss (single batch): 0.028495
# 	 partial train loss (single batch): 0.027906
# 	 partial train loss (single batch): 0.027677
# 	 partial train loss (single batch): 0.028932
# 	 partial train loss (single batch): 0.028072
# 	 partial train loss (single batch): 0.027963
# 	 partial train loss (single batch): 0.029596
# 	 partial train loss (single batch): 0.030492
# 	 partial train loss (single batch): 0.029624
# 	 partial train loss (single batch): 0.027071
# 	 partial train loss (single batch): 0.029323
# 	 partial train loss (single batch): 0.029610
# 	 partial train loss (single batch): 0.029147
# 	 partial train loss (single batch): 0.027222
# 	 partial train loss (single batch): 0.029917
# 	 partial train loss (single batch): 0.029681
# 	 partial train loss (single batch): 0.027254
# 	 partial train loss (single batch): 0.028647
# 	 partial train loss (single batch): 0.028890
# 	 partial train loss (single batch): 0.028160
# 	 partial train loss (single batch): 0.029601
# 	 partial train loss (single batch): 0.027786
# 	 partial train loss (single batch): 0.028340
# 	 partial train loss (single batch): 0.027945
# 	 partial train loss (single batch): 0.029568
# 	 partial train loss (single batch): 0.029101
# 	 partial train loss (single batch): 0.027350
# 	 partial train loss (single batch): 0.028971
# 	 partial train loss (single batch): 0.029384
# 	 partial train loss (single batch): 0.028632
# 	 partial train loss (single batch): 0.029779
# 	 partial train loss (single batch): 0.028358
# 	 partial train loss (single batch): 0.029811
# 	 partial train loss (single batch): 0.027446
# 	 partial train loss (single batch): 0.027817
# 	 partial train loss (single batch): 0.028196
# 	 partial train loss (single batch): 0.028743
# 	 partial train loss (single batch): 0.029448
# 	 partial train loss (single batch): 0.029875
# 	 partial train loss (single batch): 0.030283
# 	 partial train loss (single batch): 0.029787
# 	 partial train loss (single batch): 0.029369
# 	 partial train loss (single batch): 0.029621
# 	 partial train loss (single batch): 0.028709
# 	 partial train loss (single batch): 0.029435
# 	 partial train loss (single batch): 0.031362
# 	 partial train loss (single batch): 0.026961
# 	 partial train loss (single batch): 0.029698
# 	 partial train loss (single batch): 0.027736
# 	 partial train loss (single batch): 0.028572
# 	 partial train loss (single batch): 0.028140
# 	 partial train loss (single batch): 0.028790
# 	 partial train loss (single batch): 0.028886
# 	 partial train loss (single batch): 0.028308
# 	 partial train loss (single batch): 0.027743
# 	 partial train loss (single batch): 0.029818
# 	 partial train loss (single batch): 0.029771
# 	 partial train loss (single batch): 0.030004
# 	 partial train loss (single batch): 0.028112
# 	 partial train loss (single batch): 0.029549
# 	 partial train loss (single batch): 0.029169
# 	 partial train loss (single batch): 0.028975
# 	 partial train loss (single batch): 0.028144
# 	 partial train loss (single batch): 0.030054
# 	 partial train loss (single batch): 0.029439
# 	 partial train loss (single batch): 0.029653
# 	 partial train loss (single batch): 0.028986
# 	 partial train loss (single batch): 0.027673
# 	 partial train loss (single batch): 0.028352
# 	 partial train loss (single batch): 0.030326
# 	 partial train loss (single batch): 0.028137
# 	 partial train loss (single batch): 0.029285
# 	 partial train loss (single batch): 0.027685
# 	 partial train loss (single batch): 0.029088
# 	 partial train loss (single batch): 0.029087
# 	 partial train loss (single batch): 0.029708
# 	 partial train loss (single batch): 0.028466
# 	 partial train loss (single batch): 0.029083
# 	 partial train loss (single batch): 0.028729
# 	 partial train loss (single batch): 0.028250
# 	 partial train loss (single batch): 0.029121
# 	 partial train loss (single batch): 0.028770
# 	 partial train loss (single batch): 0.029349
# 	 partial train loss (single batch): 0.028886
# 	 partial train loss (single batch): 0.029662
# 	 partial train loss (single batch): 0.028886
# 	 partial train loss (single batch): 0.027685
# 	 partial train loss (single batch): 0.029292
# 	 partial train loss (single batch): 0.030004
# 	 partial train loss (single batch): 0.028164
# 	 partial train loss (single batch): 0.029005
# 	 partial train loss (single batch): 0.028729
# 	 partial train loss (single batch): 0.026579
# 	 partial train loss (single batch): 0.027559
# 	 partial train loss (single batch): 0.028883
# 	 partial train loss (single batch): 0.029576
#
#  EPOCH 8/30 	 train loss 0.029069600626826286 	 val loss 0.029135679826140404
# 	 partial train loss (single batch): 0.029375
# 	 partial train loss (single batch): 0.029564
# 	 partial train loss (single batch): 0.030540
# 	 partial train loss (single batch): 0.028782
# 	 partial train loss (single batch): 0.028406
# 	 partial train loss (single batch): 0.028185
# 	 partial train loss (single batch): 0.029601
# 	 partial train loss (single batch): 0.029761
# 	 partial train loss (single batch): 0.027276
# 	 partial train loss (single batch): 0.031138
# 	 partial train loss (single batch): 0.028666
# 	 partial train loss (single batch): 0.028874
# 	 partial train loss (single batch): 0.028590
# 	 partial train loss (single batch): 0.029718
# 	 partial train loss (single batch): 0.028648
# 	 partial train loss (single batch): 0.029949
# 	 partial train loss (single batch): 0.028634
# 	 partial train loss (single batch): 0.028317
# 	 partial train loss (single batch): 0.028493
# 	 partial train loss (single batch): 0.030103
# 	 partial train loss (single batch): 0.029698
# 	 partial train loss (single batch): 0.029925
# 	 partial train loss (single batch): 0.028828
# 	 partial train loss (single batch): 0.028714
# 	 partial train loss (single batch): 0.028373
# 	 partial train loss (single batch): 0.028791
# 	 partial train loss (single batch): 0.030009
# 	 partial train loss (single batch): 0.028012
# 	 partial train loss (single batch): 0.027910
# 	 partial train loss (single batch): 0.028609
# 	 partial train loss (single batch): 0.027870
# 	 partial train loss (single batch): 0.028311
# 	 partial train loss (single batch): 0.030220
# 	 partial train loss (single batch): 0.026757
# 	 partial train loss (single batch): 0.028973
# 	 partial train loss (single batch): 0.030507
# 	 partial train loss (single batch): 0.028404
# 	 partial train loss (single batch): 0.029611
# 	 partial train loss (single batch): 0.029222
# 	 partial train loss (single batch): 0.027398
# 	 partial train loss (single batch): 0.027545
# 	 partial train loss (single batch): 0.029634
# 	 partial train loss (single batch): 0.030789
# 	 partial train loss (single batch): 0.028496
# 	 partial train loss (single batch): 0.028342
# 	 partial train loss (single batch): 0.028510
# 	 partial train loss (single batch): 0.029596
# 	 partial train loss (single batch): 0.028964
# 	 partial train loss (single batch): 0.028587
# 	 partial train loss (single batch): 0.028457
# 	 partial train loss (single batch): 0.029775
# 	 partial train loss (single batch): 0.028003
# 	 partial train loss (single batch): 0.028617
# 	 partial train loss (single batch): 0.029374
# 	 partial train loss (single batch): 0.029067
# 	 partial train loss (single batch): 0.028342
# 	 partial train loss (single batch): 0.027391
# 	 partial train loss (single batch): 0.028204
# 	 partial train loss (single batch): 0.028055
# 	 partial train loss (single batch): 0.028568
# 	 partial train loss (single batch): 0.028017
# 	 partial train loss (single batch): 0.028304
# 	 partial train loss (single batch): 0.028421
# 	 partial train loss (single batch): 0.026136
# 	 partial train loss (single batch): 0.029340
# 	 partial train loss (single batch): 0.029427
# 	 partial train loss (single batch): 0.029116
# 	 partial train loss (single batch): 0.028270
# 	 partial train loss (single batch): 0.025635
# 	 partial train loss (single batch): 0.029029
# 	 partial train loss (single batch): 0.030178
# 	 partial train loss (single batch): 0.030155
# 	 partial train loss (single batch): 0.028223
# 	 partial train loss (single batch): 0.028528
# 	 partial train loss (single batch): 0.028208
# 	 partial train loss (single batch): 0.031225
# 	 partial train loss (single batch): 0.028198
# 	 partial train loss (single batch): 0.028801
# 	 partial train loss (single batch): 0.029302
# 	 partial train loss (single batch): 0.028047
# 	 partial train loss (single batch): 0.028527
# 	 partial train loss (single batch): 0.028716
# 	 partial train loss (single batch): 0.029571
# 	 partial train loss (single batch): 0.027235
# 	 partial train loss (single batch): 0.028655
# 	 partial train loss (single batch): 0.029274
# 	 partial train loss (single batch): 0.029017
# 	 partial train loss (single batch): 0.028561
# 	 partial train loss (single batch): 0.028172
# 	 partial train loss (single batch): 0.030435
# 	 partial train loss (single batch): 0.028554
# 	 partial train loss (single batch): 0.027299
# 	 partial train loss (single batch): 0.028029
# 	 partial train loss (single batch): 0.027489
# 	 partial train loss (single batch): 0.027176
# 	 partial train loss (single batch): 0.028443
# 	 partial train loss (single batch): 0.027641
# 	 partial train loss (single batch): 0.027442
# 	 partial train loss (single batch): 0.029227
# 	 partial train loss (single batch): 0.029922
# 	 partial train loss (single batch): 0.029031
# 	 partial train loss (single batch): 0.026528
# 	 partial train loss (single batch): 0.028903
# 	 partial train loss (single batch): 0.029115
# 	 partial train loss (single batch): 0.028834
# 	 partial train loss (single batch): 0.026824
# 	 partial train loss (single batch): 0.029310
# 	 partial train loss (single batch): 0.029268
# 	 partial train loss (single batch): 0.026805
# 	 partial train loss (single batch): 0.028126
# 	 partial train loss (single batch): 0.028389
# 	 partial train loss (single batch): 0.027776
# 	 partial train loss (single batch): 0.029105
# 	 partial train loss (single batch): 0.027339
# 	 partial train loss (single batch): 0.027991
# 	 partial train loss (single batch): 0.027526
# 	 partial train loss (single batch): 0.029015
# 	 partial train loss (single batch): 0.028617
# 	 partial train loss (single batch): 0.027027
# 	 partial train loss (single batch): 0.028511
# 	 partial train loss (single batch): 0.028916
# 	 partial train loss (single batch): 0.028177
# 	 partial train loss (single batch): 0.029415
# 	 partial train loss (single batch): 0.027999
# 	 partial train loss (single batch): 0.029375
# 	 partial train loss (single batch): 0.026971
# 	 partial train loss (single batch): 0.027178
# 	 partial train loss (single batch): 0.027826
# 	 partial train loss (single batch): 0.028345
# 	 partial train loss (single batch): 0.029039
# 	 partial train loss (single batch): 0.029412
# 	 partial train loss (single batch): 0.029786
# 	 partial train loss (single batch): 0.029387
# 	 partial train loss (single batch): 0.028923
# 	 partial train loss (single batch): 0.029156
# 	 partial train loss (single batch): 0.028175
# 	 partial train loss (single batch): 0.028980
# 	 partial train loss (single batch): 0.030802
# 	 partial train loss (single batch): 0.026648
# 	 partial train loss (single batch): 0.029280
# 	 partial train loss (single batch): 0.027308
# 	 partial train loss (single batch): 0.028149
# 	 partial train loss (single batch): 0.027714
# 	 partial train loss (single batch): 0.028394
# 	 partial train loss (single batch): 0.028492
# 	 partial train loss (single batch): 0.027914
# 	 partial train loss (single batch): 0.027330
# 	 partial train loss (single batch): 0.029442
# 	 partial train loss (single batch): 0.029296
# 	 partial train loss (single batch): 0.029631
# 	 partial train loss (single batch): 0.027741
# 	 partial train loss (single batch): 0.029210
# 	 partial train loss (single batch): 0.028748
# 	 partial train loss (single batch): 0.028594
# 	 partial train loss (single batch): 0.027727
# 	 partial train loss (single batch): 0.029630
# 	 partial train loss (single batch): 0.028982
# 	 partial train loss (single batch): 0.029363
# 	 partial train loss (single batch): 0.028583
# 	 partial train loss (single batch): 0.027227
# 	 partial train loss (single batch): 0.027900
# 	 partial train loss (single batch): 0.029989
# 	 partial train loss (single batch): 0.027620
# 	 partial train loss (single batch): 0.028829
# 	 partial train loss (single batch): 0.027342
# 	 partial train loss (single batch): 0.028602
# 	 partial train loss (single batch): 0.028490
# 	 partial train loss (single batch): 0.029360
# 	 partial train loss (single batch): 0.028131
# 	 partial train loss (single batch): 0.028714
# 	 partial train loss (single batch): 0.028347
# 	 partial train loss (single batch): 0.027823
# 	 partial train loss (single batch): 0.028771
# 	 partial train loss (single batch): 0.028317
# 	 partial train loss (single batch): 0.028775
# 	 partial train loss (single batch): 0.028442
# 	 partial train loss (single batch): 0.029279
# 	 partial train loss (single batch): 0.028380
# 	 partial train loss (single batch): 0.027223
# 	 partial train loss (single batch): 0.028846
# 	 partial train loss (single batch): 0.029603
# 	 partial train loss (single batch): 0.027610
# 	 partial train loss (single batch): 0.028638
# 	 partial train loss (single batch): 0.028403
# 	 partial train loss (single batch): 0.025864
# 	 partial train loss (single batch): 0.026950
# 	 partial train loss (single batch): 0.028324
# 	 partial train loss (single batch): 0.029052
#
#  EPOCH 9/30 	 train loss 0.028595494106411934 	 val loss 0.028643006458878517
# 	 partial train loss (single batch): 0.028963
# 	 partial train loss (single batch): 0.029076
# 	 partial train loss (single batch): 0.029965
# 	 partial train loss (single batch): 0.028105
# 	 partial train loss (single batch): 0.027814
# 	 partial train loss (single batch): 0.027879
# 	 partial train loss (single batch): 0.029046
# 	 partial train loss (single batch): 0.029219
# 	 partial train loss (single batch): 0.026911
# 	 partial train loss (single batch): 0.030628
# 	 partial train loss (single batch): 0.028188
# 	 partial train loss (single batch): 0.028408
# ...
# 	 partial train loss (single batch): 0.024445
# 	 partial train loss (single batch): 0.023948
# 	 partial train loss (single batch): 0.026574
# 	 partial train loss (single batch): 0.027594
# 	 partial train loss (single batch): 0.025589
# 	 partial train loss (single batch): 0.025402
# 	 partial train loss (single batch): 0.025171
# 	 partial train loss (single batch): 0.025955
# 	 partial train loss (single batch): 0.025754
# 	 partial train loss (single batch): 0.025553
# 	 partial train loss (single batch): 0.025383
# 	 partial train loss (single batch): 0.027000
# 	 partial train loss (single batch): 0.025420
# 	 partial train loss (single batch): 0.025406
# 	 partial train loss (single batch): 0.026206
# 	 partial train loss (single batch): 0.026183
# 	 partial train loss (single batch): 0.025611
# 	 partial train loss (single batch): 0.024391
# 	 partial train loss (single batch): 0.025178
# 	 partial train loss (single batch): 0.025233
# 	 partial train loss (single batch): 0.026032
# 	 partial train loss (single batch): 0.025187
# 	 partial train loss (single batch): 0.025081
# 	 partial train loss (single batch): 0.026020
# 	 partial train loss (single batch): 0.023140
# 	 partial train loss (single batch): 0.026035
# 	 partial train loss (single batch): 0.026391
# 	 partial train loss (single batch): 0.026095
# 	 partial train loss (single batch): 0.024960
# 	 partial train loss (single batch): 0.023117
# 	 partial train loss (single batch): 0.025977
# 	 partial train loss (single batch): 0.026592
# 	 partial train loss (single batch): 0.026865
# 	 partial train loss (single batch): 0.025873
# 	 partial train loss (single batch): 0.025152
# 	 partial train loss (single batch): 0.025508
# 	 partial train loss (single batch): 0.028186
# 	 partial train loss (single batch): 0.025165
# 	 partial train loss (single batch): 0.025885
# 	 partial train loss (single batch): 0.026323
# 	 partial train loss (single batch): 0.025581
# 	 partial train loss (single batch): 0.025559
# 	 partial train loss (single batch): 0.025474
# 	 partial train loss (single batch): 0.026518
# 	 partial train loss (single batch): 0.024278
# 	 partial train loss (single batch): 0.025456
# 	 partial train loss (single batch): 0.027111
# 	 partial train loss (single batch): 0.025826
# 	 partial train loss (single batch): 0.026167
# 	 partial train loss (single batch): 0.025509
# 	 partial train loss (single batch): 0.026706
# 	 partial train loss (single batch): 0.025512
# 	 partial train loss (single batch): 0.024188
# 	 partial train loss (single batch): 0.025254
# 	 partial train loss (single batch): 0.024734
# 	 partial train loss (single batch): 0.024540
# 	 partial train loss (single batch): 0.025099
# 	 partial train loss (single batch): 0.024250
# 	 partial train loss (single batch): 0.024981
# 	 partial train loss (single batch): 0.026463
# 	 partial train loss (single batch): 0.027219
# 	 partial train loss (single batch): 0.026161
# 	 partial train loss (single batch): 0.023676
# 	 partial train loss (single batch): 0.026495
# 	 partial train loss (single batch): 0.026250
# 	 partial train loss (single batch): 0.025911
# 	 partial train loss (single batch): 0.024327
# 	 partial train loss (single batch): 0.026658
# 	 partial train loss (single batch): 0.026516
# 	 partial train loss (single batch): 0.024368
# 	 partial train loss (single batch): 0.025660
# 	 partial train loss (single batch): 0.026296
# 	 partial train loss (single batch): 0.025235
# 	 partial train loss (single batch): 0.026610
# 	 partial train loss (single batch): 0.024520
# 	 partial train loss (single batch): 0.025524
# 	 partial train loss (single batch): 0.025281
# 	 partial train loss (single batch): 0.026758
# 	 partial train loss (single batch): 0.025474
# 	 partial train loss (single batch): 0.024185
# 	 partial train loss (single batch): 0.025756
# 	 partial train loss (single batch): 0.026986
# 	 partial train loss (single batch): 0.025584
# 	 partial train loss (single batch): 0.026801
# 	 partial train loss (single batch): 0.025366
# 	 partial train loss (single batch): 0.026525
# 	 partial train loss (single batch): 0.024258
# 	 partial train loss (single batch): 0.024339
# 	 partial train loss (single batch): 0.025242
# 	 partial train loss (single batch): 0.025726
# 	 partial train loss (single batch): 0.026570
# 	 partial train loss (single batch): 0.026155
# 	 partial train loss (single batch): 0.027001
# 	 partial train loss (single batch): 0.026945
# 	 partial train loss (single batch): 0.026020
# 	 partial train loss (single batch): 0.026062
# 	 partial train loss (single batch): 0.025410
# 	 partial train loss (single batch): 0.025988
# 	 partial train loss (single batch): 0.027742
# 	 partial train loss (single batch): 0.024542
# 	 partial train loss (single batch): 0.026424
# 	 partial train loss (single batch): 0.024869
# 	 partial train loss (single batch): 0.025495
# 	 partial train loss (single batch): 0.024953
# 	 partial train loss (single batch): 0.025800
# 	 partial train loss (single batch): 0.025620
# 	 partial train loss (single batch): 0.025331
# 	 partial train loss (single batch): 0.024443
# 	 partial train loss (single batch): 0.026955
# 	 partial train loss (single batch): 0.026566
# 	 partial train loss (single batch): 0.026991
# 	 partial train loss (single batch): 0.025020
# 	 partial train loss (single batch): 0.027022
# 	 partial train loss (single batch): 0.025686
# 	 partial train loss (single batch): 0.025421
# 	 partial train loss (single batch): 0.024783
# 	 partial train loss (single batch): 0.026836
# 	 partial train loss (single batch): 0.026294
# 	 partial train loss (single batch): 0.026336
# 	 partial train loss (single batch): 0.025799
# 	 partial train loss (single batch): 0.024569
# 	 partial train loss (single batch): 0.025174
# 	 partial train loss (single batch): 0.026852
# 	 partial train loss (single batch): 0.024564
# 	 partial train loss (single batch): 0.025946
# 	 partial train loss (single batch): 0.024447
# 	 partial train loss (single batch): 0.025664
# 	 partial train loss (single batch): 0.025702
# 	 partial train loss (single batch): 0.026734
# 	 partial train loss (single batch): 0.025025
# 	 partial train loss (single batch): 0.026117
# 	 partial train loss (single batch): 0.025284
# 	 partial train loss (single batch): 0.024795
# 	 partial train loss (single batch): 0.025705
# 	 partial train loss (single batch): 0.025420
# 	 partial train loss (single batch): 0.026061
# 	 partial train loss (single batch): 0.025611
# 	 partial train loss (single batch): 0.025834
# 	 partial train loss (single batch): 0.025462
# 	 partial train loss (single batch): 0.024814
# 	 partial train loss (single batch): 0.025578
# 	 partial train loss (single batch): 0.026831
# 	 partial train loss (single batch): 0.024770
# 	 partial train loss (single batch): 0.026092
# 	 partial train loss (single batch): 0.025639
# 	 partial train loss (single batch): 0.023503
# 	 partial train loss (single batch): 0.023887
# 	 partial train loss (single batch): 0.025734
# 	 partial train loss (single batch): 0.026563
#
#  EPOCH 29/30 	 train loss 0.025708112865686417 	 val loss 0.02637791633605957
# 	 partial train loss (single batch): 0.026206
# 	 partial train loss (single batch): 0.026355
# 	 partial train loss (single batch): 0.027567
# 	 partial train loss (single batch): 0.025253
# 	 partial train loss (single batch): 0.025109
# 	 partial train loss (single batch): 0.025512
# 	 partial train loss (single batch): 0.026367
# 	 partial train loss (single batch): 0.026373
# 	 partial train loss (single batch): 0.023703
# 	 partial train loss (single batch): 0.027527
# 	 partial train loss (single batch): 0.025788
# 	 partial train loss (single batch): 0.025320
# 	 partial train loss (single batch): 0.025438
# 	 partial train loss (single batch): 0.026221
# 	 partial train loss (single batch): 0.025465
# 	 partial train loss (single batch): 0.026368
# 	 partial train loss (single batch): 0.025880
# 	 partial train loss (single batch): 0.025227
# 	 partial train loss (single batch): 0.025533
# 	 partial train loss (single batch): 0.026795
# 	 partial train loss (single batch): 0.026285
# 	 partial train loss (single batch): 0.026735
# 	 partial train loss (single batch): 0.025766
# 	 partial train loss (single batch): 0.025698
# 	 partial train loss (single batch): 0.025100
# 	 partial train loss (single batch): 0.025261
# 	 partial train loss (single batch): 0.027090
# 	 partial train loss (single batch): 0.025480
# 	 partial train loss (single batch): 0.024909
# 	 partial train loss (single batch): 0.025281
# 	 partial train loss (single batch): 0.024538
# 	 partial train loss (single batch): 0.025524
# 	 partial train loss (single batch): 0.027500
# 	 partial train loss (single batch): 0.024365
# 	 partial train loss (single batch): 0.026119
# 	 partial train loss (single batch): 0.027318
# 	 partial train loss (single batch): 0.025287
# 	 partial train loss (single batch): 0.026316
# 	 partial train loss (single batch): 0.026071
# 	 partial train loss (single batch): 0.024392
# 	 partial train loss (single batch): 0.023855
# 	 partial train loss (single batch): 0.026512
# 	 partial train loss (single batch): 0.027475
# 	 partial train loss (single batch): 0.025544
# 	 partial train loss (single batch): 0.025379
# 	 partial train loss (single batch): 0.025162
# 	 partial train loss (single batch): 0.025867
# 	 partial train loss (single batch): 0.025677
# 	 partial train loss (single batch): 0.025466
# 	 partial train loss (single batch): 0.025393
# 	 partial train loss (single batch): 0.026965
# 	 partial train loss (single batch): 0.025396
# 	 partial train loss (single batch): 0.025438
# 	 partial train loss (single batch): 0.026172
# 	 partial train loss (single batch): 0.026213
# 	 partial train loss (single batch): 0.025605
# 	 partial train loss (single batch): 0.024404
# 	 partial train loss (single batch): 0.025138
# 	 partial train loss (single batch): 0.025200
# 	 partial train loss (single batch): 0.026055
# 	 partial train loss (single batch): 0.025162
# 	 partial train loss (single batch): 0.025024
# 	 partial train loss (single batch): 0.025988
# 	 partial train loss (single batch): 0.023159
# 	 partial train loss (single batch): 0.025971
# 	 partial train loss (single batch): 0.026342
# 	 partial train loss (single batch): 0.026044
# 	 partial train loss (single batch): 0.024961
# 	 partial train loss (single batch): 0.023082
# 	 partial train loss (single batch): 0.025938
# 	 partial train loss (single batch): 0.026533
# 	 partial train loss (single batch): 0.026833
# 	 partial train loss (single batch): 0.025837
# 	 partial train loss (single batch): 0.025136
# 	 partial train loss (single batch): 0.025450
# 	 partial train loss (single batch): 0.028137
# 	 partial train loss (single batch): 0.025146
# 	 partial train loss (single batch): 0.025830
# 	 partial train loss (single batch): 0.026260
# 	 partial train loss (single batch): 0.025531
# 	 partial train loss (single batch): 0.025528
# 	 partial train loss (single batch): 0.025435
# 	 partial train loss (single batch): 0.026470
# 	 partial train loss (single batch): 0.024330
# 	 partial train loss (single batch): 0.025435
# 	 partial train loss (single batch): 0.027153
# 	 partial train loss (single batch): 0.025700
# 	 partial train loss (single batch): 0.026148
# 	 partial train loss (single batch): 0.025429
# 	 partial train loss (single batch): 0.026675
# 	 partial train loss (single batch): 0.025508
# 	 partial train loss (single batch): 0.024188
# 	 partial train loss (single batch): 0.025279
# 	 partial train loss (single batch): 0.024743
# 	 partial train loss (single batch): 0.024473
# 	 partial train loss (single batch): 0.025051
# 	 partial train loss (single batch): 0.024220
# 	 partial train loss (single batch): 0.024962
# 	 partial train loss (single batch): 0.026445
# 	 partial train loss (single batch): 0.027163
# 	 partial train loss (single batch): 0.026130
# 	 partial train loss (single batch): 0.023698
# 	 partial train loss (single batch): 0.026480
# 	 partial train loss (single batch): 0.026205
# 	 partial train loss (single batch): 0.025934
# 	 partial train loss (single batch): 0.024320
# 	 partial train loss (single batch): 0.026596
# 	 partial train loss (single batch): 0.026533
# 	 partial train loss (single batch): 0.024356
# 	 partial train loss (single batch): 0.025633
# 	 partial train loss (single batch): 0.026305
# 	 partial train loss (single batch): 0.025106
# 	 partial train loss (single batch): 0.026533
# 	 partial train loss (single batch): 0.024548
# 	 partial train loss (single batch): 0.025602
# 	 partial train loss (single batch): 0.025195
# 	 partial train loss (single batch): 0.026767
# 	 partial train loss (single batch): 0.025463
# 	 partial train loss (single batch): 0.024186
# 	 partial train loss (single batch): 0.025756
# 	 partial train loss (single batch): 0.026964
# 	 partial train loss (single batch): 0.025556
# 	 partial train loss (single batch): 0.026762
# 	 partial train loss (single batch): 0.025392
# 	 partial train loss (single batch): 0.026508
# 	 partial train loss (single batch): 0.024258
# 	 partial train loss (single batch): 0.024349
# 	 partial train loss (single batch): 0.025336
# 	 partial train loss (single batch): 0.025720
# 	 partial train loss (single batch): 0.026539
# 	 partial train loss (single batch): 0.026138
# 	 partial train loss (single batch): 0.026944
# 	 partial train loss (single batch): 0.026894
# 	 partial train loss (single batch): 0.026008
# 	 partial train loss (single batch): 0.025982
# 	 partial train loss (single batch): 0.025302
# 	 partial train loss (single batch): 0.025913
# 	 partial train loss (single batch): 0.027652
# 	 partial train loss (single batch): 0.024518
# 	 partial train loss (single batch): 0.026416
# 	 partial train loss (single batch): 0.024860
# 	 partial train loss (single batch): 0.025403
# 	 partial train loss (single batch): 0.025006
# 	 partial train loss (single batch): 0.025709
# 	 partial train loss (single batch): 0.025601
# 	 partial train loss (single batch): 0.025276
# 	 partial train loss (single batch): 0.024414
# 	 partial train loss (single batch): 0.026958
# 	 partial train loss (single batch): 0.026566
# 	 partial train loss (single batch): 0.026931
# 	 partial train loss (single batch): 0.025029
# 	 partial train loss (single batch): 0.027019
# 	 partial train loss (single batch): 0.025724
# 	 partial train loss (single batch): 0.025418
# 	 partial train loss (single batch): 0.024773
# 	 partial train loss (single batch): 0.026800
# 	 partial train loss (single batch): 0.026289
# 	 partial train loss (single batch): 0.026287
# 	 partial train loss (single batch): 0.025738
# 	 partial train loss (single batch): 0.024581
# 	 partial train loss (single batch): 0.025137
# 	 partial train loss (single batch): 0.026784
# 	 partial train loss (single batch): 0.024548
# 	 partial train loss (single batch): 0.025958
# 	 partial train loss (single batch): 0.024400
# 	 partial train loss (single batch): 0.025656
# 	 partial train loss (single batch): 0.025648
# 	 partial train loss (single batch): 0.026739
# 	 partial train loss (single batch): 0.025020
# 	 partial train loss (single batch): 0.026045
# 	 partial train loss (single batch): 0.025210
# 	 partial train loss (single batch): 0.024766
# 	 partial train loss (single batch): 0.025661
# 	 partial train loss (single batch): 0.025303
# 	 partial train loss (single batch): 0.026047
# 	 partial train loss (single batch): 0.025589
# 	 partial train loss (single batch): 0.025831
# 	 partial train loss (single batch): 0.025353
# 	 partial train loss (single batch): 0.024732
# 	 partial train loss (single batch): 0.025513
# 	 partial train loss (single batch): 0.026788
# 	 partial train loss (single batch): 0.024676
# 	 partial train loss (single batch): 0.026013
# 	 partial train loss (single batch): 0.025575
# 	 partial train loss (single batch): 0.023461
# 	 partial train loss (single batch): 0.023835
# 	 partial train loss (single batch): 0.025636
# 	 partial train loss (single batch): 0.026518
#
#  EPOCH 30/30 	 train loss 0.02567008137702942 	 val loss 0.02632441185414791

# %%
plt.figure(figsize=(10,8))

plt.semilogy(dict_loss['train_loss'], label='Train')
plt.semilogy(dict_loss['val_loss'], label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
plt.legend()
plt.show()

# %%
def show_image(img):
  npimg = img.numpy()
  plt.imshow(np.transpose(npimg, (1,2,0)))

encoder.eval()
decoder.eval()

with torch.no_grad():
  # calculate the mean and std of the latent space
  images, labels = next(iter(test_loader))
  images = images.to(device)
  latent = encoder(images)
  latent = latent.cpu()

  mean = latent.mean(dim=0)
  print(mean)
  std = (latent - mean).pow(2).mean(dim=0).sqrt()
  print(std)

  # sample latent vectors from the normal distribution
  latent = torch.randn(128, d)*std + mean

  # reconstruct images from the random latent vectors
  latent = latent.to(device)
  img_recon = decoder(latent)
  img_recon = img_recon.cpu()

  fig, ax = plt.subplots(figsize=(20,8.5))
  show_image(torchvision.utils.make_grid(img_recon[:100],10,5))
  plt.show()
# Out:
# tensor([-0.0949,  0.1071, -0.0748, -0.0246])
# tensor([0.6982, 0.6431, 0.6506, 0.6515])

# %%
from tqdm import tqdm

encoded_samples = []
for sample in tqdm(test_dataset):
  img = sample[0].unsqueeze(0).to(device)
  label = sample[1]

  encoder.eval()
  with torch.no_grad():
    encoded_img = encoder(img)

  # append to list
  encoded_img = encoded_img.flatten().cpu().numpy()
  encoded_sample = {f'Enc. Variable {i}': enc for i, enc in enumerate(encoded_img)}
  encoded_sample['label'] = label
  encoded_samples.append(encoded_sample)
encoded_samples = pd.DataFrame(encoded_samples)
# Out:
# 100%|██████████| 10000/10000 [00:09<00:00, 1006.57it/s]

# %%
encoded_samples
# Out:
#       Enc. Variable 0  Enc. Variable 1  Enc. Variable 2  Enc. Variable 3  \
# 0           -2.059634         1.510498        -0.213134         0.183364
# 1            0.269593         0.610585         0.608468         0.672712
# 2           -0.175597         0.748375        -0.864148         1.184101
# 3           -0.089791        -0.805797         0.202507        -0.655394
# 4           -0.237058        -0.055593        -1.252200        -0.921084
# ...               ...              ...              ...              ...
# 9995        -0.448629         0.563236         0.847185         0.671874
# 9996         0.513956         0.425821         0.830639         0.086022
# 9997        -0.804952         0.030695        -1.315594         0.050942
# 9998        -0.336645        -0.782368        -0.116049         0.276208
# 9999         0.723481        -0.720325        -0.361425        -0.398438
#
#       label
# 0         7
# 1         2
# 2         1
# 3         0
# 4         4
# ...     ...
# 9995      2
# 9996      3
# 9997      4
# 9998      5
# 9999      6
#
# [10000 rows x 5 columns]

# %%
import plotly.express as px
px.scatter(encoded_samples, x='Enc. Variable 0', y='Enc. Variable 1',
           color=encoded_samples.label.astype(str), opacity=.7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7862bbe6-b6dd-4f32-a86c-977456907dca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7862bbe6-b6dd-4f32-a86c-977456907dca")) {                    Plotly.newPlot(                        "7862bbe6-b6dd-4f32-a86c-977456907dca",                        [{"hovertemplate":"color=7<br>Enc. Variable 0=%{x}<br>Enc. Variable 1=%{y}<extra></extra>","legendgroup":"7","marker":{"color":"#636efa","opacity":0.7,"symbol":"circle"},"mode":"markers","name":"7","showlegend":true,"x":[-2.059633731842041,-2.12404203414917,-1.4727210998535156,-1.381695032119751,-1.3149216175079346,-1.384230613708496,-1.2663090229034424,-1.6656348705291748,-2.660061836242676,-0.8399293422698975,-1.600569725036621,-0.5357868075370789,-0.8453633189201355,-0.9664572477340698,-0.30334046483039856,-0.4535508155822754,-0.6163228154182434,-0.6799455285072327,-2.235638380050659,-0.9183793663978577,-1.2960063219070435,-1.245252013206482,-1.0232504606246948,-0.5949425101280212,-0.8208245635032654,-1.5536071062088013,-1.316075086593628,-0.7936503887176514,-0.4623386859893799,-1.1713062524795532,-0.5025311708450317,-1.146308422088623,-0.7551504373550415,-0.4211297929286957,-0.3874448239803314,-0.5180259943008423,-0.5953097939491272,-1.5493587255477905,-0.8922088146209717,-0.5926980376243591,-1.349046230316162,-1.2187864780426025,-0.6371977925300598,-1.2406543493270874,-1.261207938194275,-1.425265908241272,-0.8323875665664673,-1.7094396352767944,-1.4774426221847534,-1.372096061706543,-0.7930130958557129,-0.6428931355476379,-0.06015818566083908,-1.9059334993362427,-0.47866588830947876,-1.3543838262557983,-1.0762940645217896,-0.8108689785003662,-0.6459338068962097,-1.4656580686569214,-2.809999704360962,-0.9576348662376404,-0.8176315426826477,-1.5203957557678223,-0.9533494710922241,-0.44871053099632263,-1.6417021751403809,-0.5752379298210144,0.10069900006055832,-0.7845194339752197,-0.8274890184402466,-0.4298888146877289,-1.0428893566131592,-0.5695061087608337,-1.5921239852905273,-0.6983346343040466,-1.0397619009017944,-0.6680314540863037,-0.9751142859458923,-2.608764886856079,-0.8644718527793884,-0.5766785144805908,-1.1170399188995361,-1.232941746711731,-1.0100189447402954,-1.6925280094146729,-1.0328420400619507,-0.7848776578903198,-1.8030378818511963,-0.313834547996521,-1.3869210481643677,-0.7564770579338074,-1.2983149290084839,-0.21451571583747864,-1.3510329723358154,-0.7150173783302307,-0.6930466294288635,-0.661566972732544,-0.7864682078361511,-0.6442487835884094,-0.4118821918964386,-2.6173171997070312,0.14535561203956604,-0.795840322971344,-1.1113471984863281,-0.311197966337204,-1.0230438709259033,-1.1515876054763794,-1.5479716062545776,-2.206977605819702,-0.8503540754318237,-0.6999573707580566,-0.9627559781074524,-2.026710033416748,-0.7472832798957825,-0.618107795715332,-0.8505423665046692,-0.24208945035934448,-0.7226541638374329,-0.9115856885910034,-0.6758579015731812,-0.9203290939331055,-2.170868158340454,-0.9891871213912964,-0.6613737344741821,-0.8367405533790588,0.1521332859992981,-2.2569782733917236,-0.5458941459655762,0.016756154596805573,-0.7770806550979614,-0.6675418019294739,-1.0048861503601074,-0.949854850769043,-0.5570276379585266,-1.6204962730407715,-0.9725826382637024,-1.028860092163086,-1.323819875717163,-1.0190521478652954,-0.5133293867111206,-1.4023317098617554,-1.9465900659561157,-1.833780288696289,-0.9410945177078247,-0.8849338889122009,-0.45775318145751953,-0.40588560700416565,-2.481508493423462,-1.6887633800506592,-0.09910622239112854,-0.686285674571991,-0.8247528076171875,-2.7741899490356445,-0.259212464094162,-1.9951030015945435,-1.3943908214569092,-1.095864176750183,-1.3648698329925537,-0.9651914834976196,-0.7854710817337036,-1.207706332206726,-0.8105957508087158 ...

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2)

tsne_results = tsne.fit_transform(encoded_samples.drop(['label'], axis=1))

fig = px.scatter(tsne_results, x=0, y=1,
                 color=encoded_samples.label.astype(str),
                 labels={'0': 'tsne-2d-one', '1': 'tsne-2d-two'})

fig.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning:
#
# The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="481aecb6-b0a6-4f6e-b013-08bc7f16075f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("481aecb6-b0a6-4f6e-b013-08bc7f16075f")) {                    Plotly.newPlot(                        "481aecb6-b0a6-4f6e-b013-08bc7f16075f",                        [{"hovertemplate":"color=7<br>tsne-2d-one=%{x}<br>tsne-2d-two=%{y}<extra></extra>","legendgroup":"7","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"7","showlegend":true,"x":[-34.71223449707031,-35.64385986328125,-50.163143157958984,-25.772193908691406,-36.73158264160156,-36.870887756347656,-48.5875129699707,-26.2316837310791,-36.6368293762207,-36.13810348510742,-19.092138290405273,-43.212100982666016,-41.31552505493164,-16.831350326538086,-44.0701904296875,-16.608013153076172,-13.088005065917969,-44.658851623535156,6.396368980407715,-20.71730613708496,-50.13642501831055,-22.977876663208008,-19.128244400024414,-13.091838836669922,-37.067726135253906,-26.910696029663086,-37.04082107543945,-13.21906852722168,-41.00086975097656,-43.185752868652344,-11.997810363769531,-48.10446548461914,-35.85674285888672,-14.334758758544922,-11.086202621459961,-14.955556869506836,-16.526771545410156,-37.04753875732422,-54.72058868408203,-41.578128814697266,-39.184814453125,-48.64421463012695,-16.722517013549805,-44.57881546020508,-39.28018569946289,-40.0439567565918,-19.382369995117188,-49.03362274169922,-32.3255500793457,-24.998456954956055,-43.47595977783203,-15.830132484436035,-51.513427734375,-23.94533348083496,-9.424712181091309,-16.639360427856445,-45.088279724121094,-20.612808227539062,-14.128673553466797,-26.681926727294922,-52.15231704711914,-44.78965759277344,-42.692138671875,-25.69705581665039,-33.565948486328125,-13.088150978088379,-29.62935447692871,-12.40779972076416,78.00773620605469,-36.341678619384766,-14.42846965789795,-41.473106384277344,-40.00440979003906,-43.51451873779297,-48.54649353027344,-37.76041793823242,-14.425928115844727,-37.84257125854492,-42.87786102294922,-25.927175521850586,-42.630210876464844,-37.6953239440918,-46.522369384765625,-29.628835678100586,-3.9347870349884033,-48.06621170043945,-20.86538314819336,-37.038978576660156,-30.038375854492188,-16.02962303161621,-52.71145248413086,-13.46872615814209,-42.307159423828125,-16.416887283325195,-33.89004898071289,-39.93722915649414,-20.23752212524414,-17.729488372802734,-37.86164093017578,-37.95378875732422,-37.9276123046875,-22.4661922454834,-56.839290618896484,-34.33731460571289,-33.07240295410156,-12.693903923034668,-17.580272674560547,-32.370086669921875,-29.993806838989258,-36.54542541503906,-22.72658348083496,-21.277097702026367,-39.62318801879883,-25.824100494384766,-16.7115535736084,-11.781671524047852,-14.323277473449707,49.70672607421875,-40.143192291259766,-39.66700744628906,-8.358658790588379,-36.72568130493164,-52.239253997802734,-12.71822738647461,-20.395641326904297,-36.83742904663086,28.345802307128906,-19.000741958618164,-13.965126037597656,-32.147804260253906,-42.97722625732422,-23.775354385375977,-39.12014389038086,-21.02290153503418,-29.46918296813965,-29.707477569580078,-35.19952392578125,-11.515665054321289,-30.00386619567871,-20.529342651367188,-40.38514709472656,-30.601848602294922,-35.423458099365234,-19.831741333007812,-33.59812927246094,-31.74085807800293,-22.64455795288086,-42.54438781738281,-25.504579544067383,-22.979093551635742,-17.319564819335938,-13.210708618164062,-19.0118408203125,-21.605270385742188,-45.89802932739258,-51.6663818359375,-27.82326316833496,-45.49238586425781,-31.055192947387695,-34.06251907348633,-36.56025695800781,-37.504302978515625,-20.01274299621582,-13.311152458190918,-32.93206024169922,-37.94771957397461,-36.010746002197266,-25.532283782958984,-50.035 ...
