# %% [markdown]
# **Challenge: Implement a Multiclass Classification Neural Network using PyTorch**
#
# Objective:
# Build a neural network using PyTorch to predict handwritten digits of MNIST.
#
# Steps:
#
# 1. **Data Preparation**: Load the MNIST dataset using ```torchvision.datasets.MNIST```. Standardize/normalize the features. Split the dataset into training and testing sets using, for example, ```sklearn.model_selection.train_test_split()```. **Bonus scores**: *use PyTorch's built-* ```DataLoader``` *to split the dataset*.
#
# 2. **Neural Network Architecture**: Define a simple feedforward neural network using PyTorch's ```nn.Module```. Design the input layer to match the number of features in the MNIST dataset and the output layer to have as many neurons as there are classes (10). You can experiment with the number of hidden layers and neurons to optimize the performance. **Bonus scores**: *Make your architecture flexibile to have as many hidden layers as the user wants, and use hyperparameter optimization to select the best number of hidden layeres.*
#
# 3. **Loss Function and Optimizer**: Choose an appropriate loss function for multiclass classification. Select an optimizer, like SGD (Stochastic Gradient Descent) or Adam.
#
# 4. **Training**: Write a training loop to iterate over the dataset.
# Forward pass the input through the network, calculate the loss, and perform backpropagation. Update the weights of the network using the chosen optimizer.
#
# 5. **Testing**: Evaluate the trained model on the test set. Calculate the accuracy of the model.
#
# 6. **Optimization**: Experiment with hyperparameters (learning rate, number of epochs, etc.) to optimize the model's performance. Consider adjusting the neural network architecture for better results. **Notice that you can't use the optimization algorithms from scikit-learn that we saw in lab1: e.g.,** ```GridSearchCV```.

# %%
# insert code here
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Subset

# %%
transform = transforms.Compose([transforms.ToTensor()])

# %%
trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# %%
batch_size = 32

trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=True)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, output_size, hidden_layers):
        super(NeuralNetwork, self).__init__()
        layers = []
        self.input_size = input_size
        self.output_size = output_size
        
        # input layer
        layers.append(nn.Linear(input_size, hidden_layers[0]))
        layers.append(nn.ReLU())
        
        # hidden layers
        for i in range(len(hidden_layers) - 1):
            layers.append(nn.Linear(hidden_layers[i], hidden_layers[i+1]))
            layers.append(nn.ReLU())
        
        # output layer
        layers.append(nn.Linear(hidden_layers[-1], output_size))
        self.model = nn.Sequential(*layers)
    
    def forward(self, x):
        x = x.view(-1, self.input_size)  
        return self.model(x)

# %%
# Hyperparameters
input_size = 28 * 28
output_size = 10
hidden_layers = [128, 64]

# %%
model = NeuralNetwork(input_size, output_size, hidden_layers)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
# Training Loop with accuracy

n_epochs = 20
for epoch in range(n_epochs):
  losses = []
  for inputs, labels in trainloader:
    # forward, backward, and then weight update
    y_pred = model(inputs)
    loss = loss_fn(y_pred, labels)
    losses.append(loss.item())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

  print(f'Epoch {epoch + 1} --> loss = {np.mean(losses)}')

  acc = 0
  count = 0
  for inputs, labels in testloader:
    y_pred = model(inputs)
    acc += (torch.argmax(y_pred, 1) == labels).float().sum()
    count += len(labels)
  acc /= count
  print("Epoch %d: model accuracy %.2f%%" % (epoch, acc*100))

torch.save(model.state_dict(), "cifar10model.pth")
# Out:
# Epoch 1 --> loss = 1.1600477184295654
# Epoch 0: model accuracy 88.17%
# Epoch 2 --> loss = 0.37913040666977565
# Epoch 1: model accuracy 90.75%
# Epoch 3 --> loss = 0.31166078842282297
# Epoch 2: model accuracy 92.02%
# Epoch 4 --> loss = 0.2747464917043845
# Epoch 3: model accuracy 92.90%
# Epoch 5 --> loss = 0.2458111511905988
# Epoch 4: model accuracy 93.45%
# Epoch 6 --> loss = 0.22104715250929197
# Epoch 5: model accuracy 94.03%
# Epoch 7 --> loss = 0.19925018932620683
# Epoch 6: model accuracy 94.48%
# Epoch 8 --> loss = 0.18024860512316226
# Epoch 7: model accuracy 95.05%
# Epoch 9 --> loss = 0.16365376180261373
# Epoch 8: model accuracy 95.19%
# Epoch 10 --> loss = 0.14939023410975932
# Epoch 9: model accuracy 95.76%
# Epoch 11 --> loss = 0.1367811261107524
# Epoch 10: model accuracy 96.03%
# Epoch 12 --> loss = 0.12597361603528262
# Epoch 11: model accuracy 96.23%
# Epoch 13 --> loss = 0.11655820522233844
# Epoch 12: model accuracy 96.25%
# Epoch 14 --> loss = 0.10849703327616056
# Epoch 13: model accuracy 96.58%
# Epoch 15 --> loss = 0.10104781071022152
# Epoch 14: model accuracy 96.74%
# Epoch 16 --> loss = 0.09430826707308491
# Epoch 15: model accuracy 96.80%
# Epoch 17 --> loss = 0.08866925382638971
# Epoch 16: model accuracy 97.02%
# Epoch 18 --> loss = 0.08314984779531757
# Epoch 17: model accuracy 97.04%
# Epoch 19 --> loss = 0.07842334061687191
# Epoch 18: model accuracy 97.18%
# Epoch 20 --> loss = 0.07371666472305854
# Epoch 19: model accuracy 97.20%

# %%
model.eval()
correct = 0
total = 0

# %%
# Accuracy

with torch.no_grad():
    for images, labels in testloader:
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = correct / total
print(f"Accuracy on test set: {accuracy * 100:.2f}%")
# Out:
# Accuracy on test set: 97.20%

# %%
# Optimizing

learning_rates = [0.001, 0.01, 0.1]
num_epochs_list = [5, 10, 15]
hidden_layer_sizes = [[128, 64], [256, 128, 64], [64, 32]]
batch_sizes = [32, 64, 128]

best_accuracy = 0.0
best_hyperparameters = {}

# Iterate through hyperparameters
for lr in learning_rates:
    for num_epochs in num_epochs_list:
        for hidden_layers in hidden_layer_sizes:
            for batch_size in batch_sizes:
                # DataLoader 
                trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True)
                testloader = DataLoader(testset,batch_size=batch_size, shuffle=False)
                
                # create the model
                model = NeuralNetwork(input_size, output_size, hidden_layers)
                optimizer = optim.SGD(model.parameters(), lr=lr)
                
                # train the model and evaluate
                n_epochs = 20
                for epoch in range(n_epochs):
                  losses = []
                  for inputs, labels in trainloader:
                    # forward, backward and weight update
                    y_pred = model(inputs)
                    loss = loss_fn(y_pred, labels)
                    losses.append(loss.item())
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()
                  print(f'Epoch {epoch + 1} --> loss = {np.mean(losses)}')
                  acc = 0
                  count = 0
                  for inputs, labels in testloader:
                    y_pred = model(inputs)
                    acc += (torch.argmax(y_pred, 1) == labels).float().sum()
                    count += len(labels)
                  acc /= count
                  print("Epoch %d: model accuracy %.2f%%" % (epoch, acc*100))
                
                # Check if hyperparameters give a better accuracy
                if accuracy > best_accuracy:
                    best_accuracy = accuracy
                    best_hyperparameters = {
                        'learning_rate': lr,
                        'num_epochs': num_epochs,
                        'hidden_layers': hidden_layers,
                        'batch_size': batch_size
                    }

print("Best Accuracy:", best_accuracy)
print("Best Hyperparameters:", best_hyperparameters)
# Out:
# Epoch 1 --> loss = 2.279031266784668
# Epoch 0: model accuracy 30.22%
# Epoch 2 --> loss = 2.1683673913319907
# Epoch 1: model accuracy 63.50%
# Epoch 3 --> loss = 1.8736804149627686
# Epoch 2: model accuracy 71.16%
# Epoch 4 --> loss = 1.3527560563087464
# Epoch 3: model accuracy 77.36%
# Epoch 5 --> loss = 0.9267922252496084
# Epoch 4: model accuracy 81.15%
# Epoch 6 --> loss = 0.7155301062742869
# Epoch 5: model accuracy 83.87%
# Epoch 7 --> loss = 0.6030998376687368
# Epoch 6: model accuracy 85.45%
# Epoch 8 --> loss = 0.533059915359815
# Epoch 7: model accuracy 86.68%
# Epoch 9 --> loss = 0.48524137518405913
# Epoch 8: model accuracy 87.74%
# Epoch 10 --> loss = 0.45091147241592405
# Epoch 9: model accuracy 88.30%
# Epoch 11 --> loss = 0.42497333874702453
# Epoch 10: model accuracy 88.68%
# Epoch 12 --> loss = 0.404754472275575
# Epoch 11: model accuracy 89.26%
# Epoch 13 --> loss = 0.38868677516380945
# Epoch 12: model accuracy 89.79%
# Epoch 14 --> loss = 0.37558669815460843
# Epoch 13: model accuracy 90.04%
# Epoch 15 --> loss = 0.3645076171596845
# Epoch 14: model accuracy 90.29%
# Epoch 16 --> loss = 0.3551695703307788
# Epoch 15: model accuracy 90.44%
# Epoch 17 --> loss = 0.34692647376060487
# Epoch 16: model accuracy 90.61%
# Epoch 18 --> loss = 0.33983663988113405
# Epoch 17: model accuracy 90.88%
# Epoch 19 --> loss = 0.3334010875940323
# Epoch 18: model accuracy 90.89%
# Epoch 20 --> loss = 0.32758136469920474
# Epoch 19: model accuracy 91.19%
# Epoch 1 --> loss = 2.289532200614018
# Epoch 0: model accuracy 23.38%
# Epoch 2 --> loss = 2.256547228105541
# Epoch 1: model accuracy 34.20%
# Epoch 3 --> loss = 2.206517528623406
# Epoch 2: model accuracy 43.91%
# Epoch 4 --> loss = 2.122657359281837
# Epoch 3: model accuracy 51.51%
# Epoch 5 --> loss = 1.9824922866404437
# Epoch 4: model accuracy 59.34%
# Epoch 6 --> loss = 1.7687397268789409
# Epoch 5: model accuracy 65.21%
# Epoch 7 --> loss = 1.4992256862268265
# Epoch 6: model accuracy 71.04%
# Epoch 8 --> loss = 1.2345850196982753
# Epoch 7: model accuracy 75.19%
# Epoch 9 --> loss = 1.0265562349418078
# Epoch 8: model accuracy 78.74%
# Epoch 10 --> loss = 0.8792658950220039
# Epoch 9: model accuracy 80.68%
# Epoch 11 --> loss = 0.7749961068126947
# Epoch 10: model accuracy 81.91%
# Epoch 12 --> loss = 0.6982834481481296
# Epoch 11: model accuracy 83.31%
# Epoch 13 --> loss = 0.6399654611341481
# Epoch 12: model accuracy 84.25%
# Epoch 14 --> loss = 0.5941601516976793
# Epoch 13: model accuracy 85.28%
# Epoch 15 --> loss = 0.557458461919573
# Epoch 14: model accuracy 85.86%
# Epoch 16 --> loss = 0.5276533310919174
# Epoch 15: model accuracy 86.45%
# Epoch 17 --> loss = 0.5031503092632619
# Epoch 16: model accuracy 87.09%
# Epoch 18 --> loss = 0.48251610589243454
# Epoch 17: model accuracy 87.35%
# Epoch 19 --> loss = 0.4654069588954515
# Epoch 18: model accuracy 87.64%
# Epoch 20 --> loss = 0.45055456005179806
# Epoch 19: model accuracy 88.09%
# Epoch 1 --> loss = 2.3015251408762007
# Epoch 0: model accuracy 14.33%
# Epoch 2 --> loss = 2.2871869189906984
# Epoch 1: model accuracy 21.20%
# Epoch 3 --> loss = 2.2703548072497726
# Epoch 2: model accuracy 28.41%
# Epoch 4 --> loss = 2.2500074911219223
# Epoch 3: model accuracy 32.09%
# Epoch 5 --> loss = 2.2246071621299044
# Epoch 4: model accuracy 34.47%
# Epoch 6 --> loss = 2.1921186325138313
# Epoch 5: model accuracy 38.39%
# Epoch 7 --> loss = 2.1502340490629934
# Epoch 6: model accuracy 48.17%
# Epoch 8 --> loss = 2.0964141878237856
# Epoch 7: model accuracy 53.04%
# Epoch 9 --> loss = 2.0274689344963286
# Epoch 8: model accuracy 56.17%
# Epoch 10 --> loss = 1.9402552197482794
# Epoch 9: model accuracy 59.65%
# Epoch 11 --> loss = 1.833363441007732
# Epoch 10: model accuracy 62.45%
# Epoch 12 --> loss = 1.7084699353175377
# Epoch 11: model accuracy 64.79%
# Epoch 13 --> loss = 1.570884439990973
# Epoch 12: model accuracy 66.95%
# Epoch 14 --> loss = 1.4295330601714566
# Epoch 13: model accuracy 70.01%
# Epoch 15 --> loss = 1.2944329367009306
# Epoch 14: model accuracy 72.79%
# Epoch 16 --> loss = 1.173403134224003
# Epoch 15: model accuracy 75.45%
# Epoch 17 --> loss = 1.0693349182478655
# Epoch 16: model accuracy 77.65%
# Epoch 18 --> loss = 0.9819918872196791
# Epoch 17: model accuracy 78.78%
# Epoch 19 --> loss = 0.9089429842383623
# Epoch 18: model accuracy 80.00%
# Epoch 20 --> loss = 0.8480618996406669
# Epoch 19: model accuracy 80.78%
# Epoch 1 --> loss = 2.297769237009684
# Epoch 0: model accuracy 14.86%
# Epoch 2 --> loss = 2.2820858908335366
# Epoch 1: model accuracy 16.85%
# Epoch 3 --> loss = 2.256764948018392
# Epoch 2: model accuracy 43.63%
# Epoch 4 --> loss = 2.200229553604126
# Epoch 3: model accuracy 51.93%
# Epoch 5 --> loss = 2.0502275714238483
# Epoch 4: model accuracy 54.05%
# Epoch 6 --> loss = 1.669274686304728
# Epoch 5: model accuracy 68.48%
# Epoch 7 --> loss = 1.1307982370376586
# Epoch 6: model accuracy 76.90%
# Epoch 8 --> loss = 0.8083448596954346
# Epoch 7: model accuracy 80.49%
# Epoch 9 --> loss = 0.6627531574408213
# Epoch 8: model accuracy 82.98%
# Epoch 10 --> loss = 0.5830764273325603
# Epoch 9: model accuracy 84.90%
# Epoch 11 --> loss = 0.5305153473456701
# Epoch 10: model accuracy 85.85%
# Epoch 12 --> loss = 0.4917505853096644
# Epoch 11: model accuracy 86.95%
# Epoch 13 --> loss = 0.4616871999502182
# Epoch 12: model accuracy 87.63%
# Epoch 14 --> loss = 0.4374785184661547
# Epoch 13: model accuracy 88.28%
# Epoch 15 --> loss = 0.41695039879481
# Epoch 14: model accuracy 88.68%
# Epoch 16 --> loss = 0.39982916795810064
# Epoch 15: model accuracy 89.19%
# Epoch 17 --> loss = 0.3849163000543912
# Epoch 16: model accuracy 89.39%
# Epoch 18 --> loss = 0.37210530565977096
# Epoch 17: model accuracy 89.64%
# Epoch 19 --> loss = 0.3606037602146467
# Epoch 18: model accuracy 89.91%
# Epoch 20 --> loss = 0.35034346236387887
# Epoch 19: model accuracy 90.27%
# Epoch 1 --> loss = 2.300329267851579
# Epoch 0: model accuracy 9.80%
# Epoch 2 --> loss = 2.2931381624136398
# Epoch 1: model accuracy 9.80%
# Epoch 3 --> loss = 2.28447307681224
# Epoch 2: model accuracy 12.22%
# Epoch 4 --> loss = 2.272409487380656
# Epoch 3: model accuracy 27.90%
# Epoch 5 --> loss = 2.254728431894835
# Epoch 4: model accuracy 34.24%
# Epoch 6 --> loss = 2.227874570563912
# Epoch 5: model accuracy 35.23%
# Epoch 7 --> loss = 2.1837280691305456
# Epoch 6: model accuracy 37.30%
# Epoch 8 --> loss = 2.1101670346534585
# Epoch 7: model accuracy 40.50%
# Epoch 9 --> loss = 1.9914448379453566
# Epoch 8: model accuracy 46.02%
# Epoch 10 --> loss = 1.8173266365838203
# Epoch 9: model accuracy 54.86%
# Epoch 11 --> loss = 1.5773194192060784
# Epoch 10: model accuracy 65.29%
# Epoch 12 --> loss = 1.2924638356227103
# Epoch 11: model accuracy 71.80%
# Epoch 13 --> loss = 1.045827674204861
# Epoch 12: model accuracy 75.59%
# Epoch 14 --> loss = 0.8770468250266524
# Epoch 13: model accuracy 78.16%
# Epoch 15 --> loss = 0.7673302094247549
# Epoch 14: model accuracy 79.84%
# Epoch 16 --> loss = 0.6918019617417219
# Epoch 15: model accuracy 81.18%
# Epoch 17 --> loss = 0.6362999536589519
# Epoch 16: model accuracy 82.56%
# Epoch 18 --> loss = 0.593291367612668
# Epoch 17: model accuracy 83.82%
# Epoch 19 --> loss = 0.5592405255923647
# Epoch 18: model accuracy 84.54%
# Epoch 20 --> loss = 0.5310651055976018
# Epoch 19: model accuracy 85.37%
# Epoch 1 --> loss = 2.3019022489153245
# Epoch 0: model accuracy 9.82%
# Epoch 2 --> loss = 2.298674578859862
# Epoch 1: model accuracy 9.89%
# Epoch 3 --> loss = 2.2953886696016355
# Epoch 2: model accuracy 10.49%
# Epoch 4 --> loss = 2.291951056482441
# Epoch 3: model accuracy 12.95%
# Epoch 5 --> loss = 2.2882514594714523
# Epoch 4: model accuracy 15.93%
# Epoch 6 --> loss = 2.284165027553339
# Epoch 5: model accuracy 19.68%
# Epoch 7 --> loss = 2.279521628483526
# Epoch 6: model accuracy 28.94%
# Epoch 8 --> loss = 2.274124262429504
# Epoch 7: model accuracy 37.99%
# Epoch 9 --> loss = 2.2677679814255316
# Epoch 8: model accuracy 46.55%
# Epoch 10 --> loss = 2.260215461889564
# Epoch 9: model accuracy 54.00%
# Epoch 11 --> loss = 2.2511034921796593
# Epoch 10: model accuracy 59.93%
# Epoch 12 --> loss = 2.2399444036138085
# Epoch 11: model accuracy 63.03%
# Epoch 13 --> loss = 2.2259595516139763
# Epoch 12: model accuracy 65.25%
# Epoch 14 --> loss = 2.2080772482255884
# Epoch 13: model accuracy 65.13%
# Epoch 15 --> loss = 2.184899446044141
# Epoch 14: model accuracy 64.73%
# Epoch 16 --> loss = 2.1546140103451985
# Epoch 15: model accuracy 63.60%
# Epoch 17 --> loss = 2.1148130751367824
# Epoch 16: model accuracy 62.22%
# Epoch 18 --> loss = 2.0625316819656634
# Epoch 17: model accuracy 61.34%
# Epoch 19 --> loss = 1.9945397534604266
# Epoch 18: model accuracy 61.92%
# Epoch 20 --> loss = 1.907703367631827
# Epoch 19: model accuracy 63.22%
# Epoch 1 --> loss = 2.282760657374064
# Epoch 0: model accuracy 24.27%
# Epoch 2 --> loss = 2.19594582379659
# Epoch 1: model accuracy 38.52%
# Epoch 3 --> loss = 1.9800435485839845
# Epoch 2: model accuracy 55.22%
# Epoch 4 --> loss = 1.5838826105117798
# Epoch 3: model accuracy 68.76%
# Epoch 5 --> loss = 1.1188675949732463
# Epoch 4: model accuracy 79.36%
# Epoch 6 --> loss = 0.8163559772491455
# Epoch 5: model accuracy 82.38%
# Epoch 7 --> loss = 0.6602443010807038
# Epoch 6: model accuracy 84.52%
# Epoch 8 --> loss = 0.5747545686880747
# Epoch 7: model accuracy 85.61%
# Epoch 9 --> loss = 0.5227065925757091
# Epoch 8: model accuracy 86.54%
# Epoch 10 --> loss = 0.4876017794370651
# Epoch 9: model accuracy 87.04%
# Epoch 11 --> loss = 0.4616832200129827
# Epoch 10: model accuracy 87.60%
# Epoch 12 --> loss = 0.4416201115767161
# Epoch 11: model accuracy 87.90%
# Epoch 13 --> loss = 0.4252532140771548
# Epoch 12: model accuracy 88.23%
# Epoch 14 --> loss = 0.41144026514689125
# Epoch 13: model accuracy 88.75%
# Epoch 15 --> loss = 0.3995064773360888
# Epoch 14: model accuracy 88.93%
# Epoch 16 --> loss = 0.389057781624794
# Epoch 15: model accuracy 89.23%
# Epoch 17 --> loss = 0.37970834279457727
# Epoch 16: model accuracy 89.45%
# Epoch 18 --> loss = 0.37135465441942217
# Epoch 17: model accuracy 89.67%
# Epoch 19 --> loss = 0.36378100526730217
# Epoch 18: model accuracy 89.96%
# Epoch 20 --> loss = 0.3567640455802282
# Epoch 19: model accuracy 90.07%
# Epoch 1 --> loss = 2.299011688242589
# Epoch 0: model accuracy 24.65%
# Epoch 2 --> loss = 2.2688446111008047
# Epoch 1: model accuracy 34.29%
# Epoch 3 --> loss = 2.226055557031367
# Epoch 2: model accuracy 37.89%
# Epoch 4 --> loss = 2.1578805352579047
# Epoch 3: model accuracy 49.44%
# Epoch 5 --> loss = 2.046535017902155
# Epoch 4: model accuracy 51.56%
# Epoch 6 --> loss = 1.8739368624524522
# Epoch 5: model accuracy 52.75%
# Epoch 7 --> loss = 1.6434592264039176
# Epoch 6: model accuracy 59.25%
# Epoch 8 --> loss = 1.3871317845163569
# Epoch 7: model accuracy 67.85%
# Epoch 9 --> loss = 1.1576253722852736
# Epoch 8: model accuracy 74.64%
# Epoch 10 --> loss = 0.9846964315183635
# Epoch 9: model accuracy 77.84%
# Epoch 11 --> loss = 0.862002572906551
# Epoch 10: model accuracy 79.67%
# Epoch 12 --> loss = 0.773486618230592
# Epoch 11: model accuracy 81.51%
# Epoch 13 --> loss = 0.7067876778749514
# Epoch 12: model accuracy 82.81%
# Epoch 14 --> loss = 0.6542268812275136
# Epoch 13: model accuracy 83.82%
# Epoch 15 --> loss = 0.6107222249767165
# Epoch 14: model accuracy 84.82%
# Epoch 16 --> loss = 0.574229550387051
# Epoch 15: model accuracy 85.71%
# Epoch 17 --> loss = 0.5428044495107268
# Epoch 16: model accuracy 86.49%
# Epoch 18 --> loss = 0.515852496599846
# Epoch 17: model accuracy 86.95%
# Epoch 19 --> loss = 0.49252091243322976
# Epoch 18: model accuracy 87.48%
# Epoch 20 --> loss = 0.47250919763658095
# Epoch 19: model accuracy 87.87%
# Epoch 1 --> loss = 2.305397276176827
# Epoch 0: model accuracy 8.94%
# Epoch 2 --> loss = 2.29584801934167
# Epoch 1: model accuracy 10.96%
# Epoch 3 --> loss = 2.283758549802085
# Epoch 2: model accuracy 18.26%
# Epoch 4 --> loss = 2.2685849824185564
# Epoch 3: model accuracy 28.96%
# Epoch 5 --> loss = 2.24887382602895
# Epoch 4: model accuracy 42.41%
# Epoch 6 --> loss = 2.222930480168064
# Epoch 5: model accuracy 53.26%
# Epoch 7 --> loss = 2.1896695160408264
# Epoch 6: model accuracy 54.18%
# Epoch 8 --> loss = 2.1478243148657303
# Epoch 7: model accuracy 52.76%
# Epoch 9 --> loss = 2.095721384101331
# Epoch 8: model accuracy 51.36%
# Epoch 10 --> loss = 2.0314445429519297
# Epoch 9: model accuracy 50.32%
# Epoch 11 --> loss = 1.9537995115780373
# Epoch 10: model accuracy 50.22%
# Epoch 12 --> loss = 1.8637522108265077
# Epoch 11: model accuracy 50.79%
# Epoch 13 --> loss = 1.7647299242934693
# Epoch 12: model accuracy 52.68%
# Epoch 14 --> loss = 1.6596896231555736
# Epoch 13: model accuracy 56.90%
# Epoch 15 --> loss = 1.5507051423668607
# Epoch 14: model accuracy 61.99%
# Epoch 16 --> loss = 1.439783634407434
# Epoch 15: model accuracy 66.29%
# Epoch 17 --> loss = 1.3298388800895544
# Epoch 16: model accuracy 69.98%
# Epoch 18 --> loss = 1.2250838465273761
# Epoch 17: model accuracy 72.76%
# Epoch 19 --> loss = 1.128747488262811
# Epoch 18: model accuracy 74.47%
# Epoch 20 --> loss = 1.042729490601432
# Epoch 19: model accuracy 76.17%
# Epoch 1 --> loss = 2.2738536001841227
# Epoch 0: model accuracy 28.07%
# Epoch 2 --> loss = 2.167726560465495
# Epoch 1: model accuracy 54.83%
# Epoch 3 --> loss = 1.8861539265314737
# Epoch 2: model accuracy 60.06%
# Epoch 4 --> loss = 1.4056908228238423
# Epoch 3: model accuracy 72.10%
# Epoch 5 --> loss = 1.0042358534495035
# Epoch 4: model accuracy 79.12%
# Epoch 6 --> loss = 0.7745090553601582
# Epoch 5: model accuracy 81.82%
# Epoch 7 --> loss = 0.6441841870784759
# Epoch 6: model accuracy 84.23%
# Epoch 8 --> loss = 0.5628040213902792
# Epoch 7: model accuracy 85.88%
# Epoch 9 --> loss = 0.50789422955513
# Epoch 8: model accuracy 87.07%
# Epoch 10 --> loss = 0.46832512384255726
# Epoch 9: model accuracy 87.92%
# Epoch 11 --> loss = 0.4387116998195648
# Epoch 10: model accuracy 88.71%
# Epoch 12 --> loss = 0.41592106446027755
# Epoch 11: model accuracy 88.98%
# Epoch 13 --> loss = 0.3978471995949745
# Epoch 12: model accuracy 89.29%
# Epoch 14 --> loss = 0.38320536607901257
# Epoch 13: model accuracy 89.63%
# Epoch 15 --> loss = 0.37101023990710574
# Epoch 14: model accuracy 90.19%
# Epoch 16 --> loss = 0.3607619080702464
# Epoch 15: model accuracy 90.25%
# Epoch 17 --> loss = 0.351835668694973
# Epoch 16: model accuracy 90.40%
# Epoch 18 --> loss = 0.3440174667298794
# Epoch 17: model accuracy 90.53%
# Epoch 19 --> loss = 0.33690790305137636
# Epoch 18: model accuracy 90.74%
# Epoch 20 --> loss = 0.33057743165691694
# Epoch 19: model accuracy 90.85%
# Epoch 1 --> loss = 2.2898497896662144
# Epoch 0: model accuracy 23.86%
# Epoch 2 --> loss = 2.259168532865642
# Epoch 1: model accuracy 36.77%
# Epoch 3 --> loss = 2.2119849544089996
# Epoch 2: model accuracy 49.87%
# Epoch 4 --> loss = 2.133007565541054
# Epoch 3: model accuracy 54.48%
# Epoch 5 --> loss = 2.0032107174269425
# Epoch 4: model accuracy 58.81%
# Epoch 6 --> loss = 1.8056835194132221
# Epoch 5: model accuracy 63.94%
# Epoch 7 --> loss = 1.5476788789478702
# Epoch 6: model accuracy 68.39%
# Epoch 8 --> loss = 1.2840196844230074
# Epoch 7: model accuracy 72.44%
# Epoch 9 --> loss = 1.0727315496152907
# Epoch 8: model accuracy 75.97%
# Epoch 10 --> loss = 0.9237416501619669
# Epoch 9: model accuracy 78.08%
# Epoch 11 --> loss = 0.8185438881677859
# Epoch 10: model accuracy 80.40%
# Epoch 12 --> loss = 0.7406921218643819
# Epoch 11: model accuracy 81.91%
# Epoch 13 --> loss = 0.6805038244358258
# Epoch 12: model accuracy 83.18%
# Epoch 14 --> loss = 0.6317572457703955
# Epoch 13: model accuracy 84.33%
# Epoch 15 --> loss = 0.5914746177539643
# Epoch 14: model accuracy 85.10%
# Epoch 16 --> loss = 0.5577931084167729
# Epoch 15: model accuracy 85.82%
# Epoch 17 --> loss = 0.5295473026441359
# Epoch 16: model accuracy 86.47%
# Epoch 18 --> loss = 0.5057103589081815
# Epoch 17: model accuracy 86.88%
# Epoch 19 --> loss = 0.4853094084653011
# Epoch 18: model accuracy 87.43%
# Epoch 20 --> loss = 0.4680083200399047
# Epoch 19: model accuracy 87.68%
# Epoch 1 --> loss = 2.302135773559115
# Epoch 0: model accuracy 14.28%
# Epoch 2 --> loss = 2.290669238389428
# Epoch 1: model accuracy 15.88%
# Epoch 3 --> loss = 2.2771041738961553
# Epoch 2: model accuracy 17.57%
# Epoch 4 --> loss = 2.2611796352654885
# Epoch 3: model accuracy 25.07%
# Epoch 5 --> loss = 2.241646266441101
# Epoch 4: model accuracy 38.77%
# Epoch 6 --> loss = 2.2166920135270303
# Epoch 5: model accuracy 47.99%
# Epoch 7 --> loss = 2.1846781056572886
# Epoch 6: model accuracy 54.11%
# Epoch 8 --> loss = 2.1432364785086624
# Epoch 7: model accuracy 58.23%
# Epoch 9 --> loss = 2.0890539439756477
# Epoch 8: model accuracy 60.06%
# Epoch 10 --> loss = 2.0182883358205053
# Epoch 9: model accuracy 61.27%
# Epoch 11 --> loss = 1.9272932922408017
# Epoch 10: model accuracy 62.09%
# Epoch 12 --> loss = 1.8143900953122039
# Epoch 11: model accuracy 63.48%
# Epoch 13 --> loss = 1.6824193511690413
# Epoch 12: model accuracy 65.76%
# Epoch 14 --> loss = 1.539051011427125
# Epoch 13: model accuracy 69.09%
# Epoch 15 --> loss = 1.3955198628053482
# Epoch 14: model accuracy 72.02%
# Epoch 16 --> loss = 1.2619182827121922
# Epoch 15: model accuracy 74.28%
# Epoch 17 --> loss = 1.1440504195847745
# Epoch 16: model accuracy 76.41%
# Epoch 18 --> loss = 1.043869299420924
# Epoch 17: model accuracy 77.83%
# Epoch 19 --> loss = 0.9603775904885233
# Epoch 18: model accuracy 78.75%
# Epoch 20 --> loss = 0.8909977679567804
# Epoch 19: model accuracy 79.90%
# Epoch 1 --> loss = 2.301518516921997
# Epoch 0: model accuracy 19.99%
# Epoch 2 --> loss = 2.2863210388183592
# Epoch 1: model accuracy 26.70%
# Epoch 3 --> loss = 2.259911127471924
# Epoch 2: model accuracy 44.02%
# Epoch 4 --> loss = 2.2011409900665284
# Epoch 3: model accuracy 42.96%
# Epoch 5 --> loss = 2.049199212646484
# Epoch 4: model accuracy 47.16%
# Epoch 6 --> loss = 1.7196798583984374
# Epoch 5: model accuracy 62.77%
# Epoch 7 --> loss = 1.2452391189575196
# Epoch 6: model accuracy 72.67%
# Epoch 8 --> loss = 0.9082272164026897
# Epoch 7: model accuracy 78.37%
# Epoch 9 --> loss = 0.736299500020345
# Epoch 8: model accuracy 80.60%
# Epoch 10 --> loss = 0.6396055424213409
# Epoch 9: model accuracy 82.87%
# Epoch 11 --> loss = 0.5740139428297678
# Epoch 10: model accuracy 84.38%
# Epoch 12 --> loss = 0.5268951901753743
# Epoch 11: model accuracy 85.41%
# Epoch 13 --> loss = 0.49212675580978393
# Epoch 12: model accuracy 86.22%
# Epoch 14 --> loss = 0.4650433006922404
# Epoch 13: model accuracy 86.87%
# Epoch 15 --> loss = 0.4433509147882462
# Epoch 14: model accuracy 87.61%
# Epoch 16 --> loss = 0.42454050821860634
# Epoch 15: model accuracy 88.01%
# Epoch 17 --> loss = 0.408417109755675
# Epoch 16: model accuracy 88.60%
# Epoch 18 --> loss = 0.3939303685029348
# Epoch 17: model accuracy 89.11%
# Epoch 19 --> loss = 0.38088323152860004
# Epoch 18: model accuracy 89.49%
# Epoch 20 --> loss = 0.36905765695174536
# Epoch 19: model accuracy 89.84%
# Epoch 1 --> loss = 2.3022011696402704
# Epoch 0: model accuracy 10.68%
# Epoch 2 --> loss = 2.2949631661494405
# Epoch 1: model accuracy 12.68%
# Epoch 3 --> loss = 2.2866975928166275
# Epoch 2: model accuracy 17.92%
# Epoch 4 --> loss = 2.2765842414359803
# Epoch 3: model accuracy 25.44%
# Epoch 5 --> loss = 2.263200266528994
# Epoch 4: model accuracy 33.13%
# Epoch 6 --> loss = 2.243732510090891
# Epoch 5: model accuracy 44.58%
# Epoch 7 --> loss = 2.213176057536973
# Epoch 6: model accuracy 44.38%
# Epoch 8 --> loss = 2.1621964130320275
# Epoch 7: model accuracy 41.20%
# Epoch 9 --> loss = 2.073918520768822
# Epoch 8: model accuracy 37.78%
# Epoch 10 --> loss = 1.9300894860519784
# Epoch 9: model accuracy 38.55%
# Epoch 11 --> loss = 1.7407360585259477
# Epoch 10: model accuracy 48.45%
# Epoch 12 --> loss = 1.5297478835211633
# Epoch 11: model accuracy 61.74%
# Epoch 13 --> loss = 1.3153467360081703
# Epoch 12: model accuracy 68.73%
# Epoch 14 --> loss = 1.1243976590984157
# Epoch 13: model accuracy 71.98%
# Epoch 15 --> loss = 0.9681616679056367
# Epoch 14: model accuracy 75.67%
# Epoch 16 --> loss = 0.8462637823654898
# Epoch 15: model accuracy 78.43%
# Epoch 17 --> loss = 0.7518030700526004
# Epoch 16: model accuracy 80.63%
# Epoch 18 --> loss = 0.6778847305759438
# Epoch 17: model accuracy 81.95%
# Epoch 19 --> loss = 0.6204331393943412
# Epoch 18: model accuracy 83.35%
# Epoch 20 --> loss = 0.5760725421437831
# Epoch 19: model accuracy 84.44%
# Epoch 1 --> loss = 2.3035083244095986
# Epoch 0: model accuracy 9.86%
# Epoch 2 --> loss = 2.3014164342046546
# Epoch 1: model accuracy 10.38%
# Epoch 3 --> loss = 2.2993518889331614
# Epoch 2: model accuracy 12.42%
# Epoch 4 --> loss = 2.2972539635355282
# Epoch 3: model accuracy 15.17%
# Epoch 5 --> loss = 2.2950789603088966
# Epoch 4: model accuracy 17.62%
# Epoch 6 --> loss = 2.2927716988236155
# Epoch 5: model accuracy 20.06%
# Epoch 7 --> loss = 2.2902832361680865
# Epoch 6: model accuracy 21.68%
# Epoch 8 --> loss = 2.2875486884289966
# Epoch 7: model accuracy 24.32%
# Epoch 9 --> loss = 2.284511111184224
# Epoch 8: model accuracy 30.12%
# Epoch 10 --> loss = 2.2811170280106796
# Epoch 9: model accuracy 33.01%
# Epoch 11 --> loss = 2.2772608504874876
# Epoch 10: model accuracy 34.36%
# Epoch 12 --> loss = 2.2728157887326628
# Epoch 11: model accuracy 35.23%
# Epoch 13 --> loss = 2.267595633260731
# Epoch 12: model accuracy 35.64%
# Epoch 14 --> loss = 2.2613987531234967
# Epoch 13: model accuracy 35.86%
# Epoch 15 --> loss = 2.2539556006124535
# Epoch 14: model accuracy 37.07%
# Epoch 16 --> loss = 2.244910528919082
# Epoch 15: model accuracy 38.97%
# Epoch 17 --> loss = 2.2337927660708234
# Epoch 16: model accuracy 40.95%
# Epoch 18 --> loss = 2.2199504177199243
# Epoch 17: model accuracy 42.14%
# Epoch 19 --> loss = 2.202477310766289
# Epoch 18: model accuracy 42.37%
# Epoch 20 --> loss = 2.180120365451902
# Epoch 19: model accuracy 41.52%
# Epoch 1 --> loss = 2.280286373011271
# Epoch 0: model accuracy 20.13%
# Epoch 2 --> loss = 2.1686452209472655
# Epoch 1: model accuracy 39.38%
# Epoch 3 --> loss = 1.9133341636657715
# Epoch 2: model accuracy 53.10%
# Epoch 4 --> loss = 1.4908475272496542
# Epoch 3: model accuracy 69.88%
# Epoch 5 --> loss = 1.0770447734196982
# Epoch 4: model accuracy 77.47%
# Epoch 6 --> loss = 0.8155035322348276
# Epoch 5: model accuracy 81.14%
# Epoch 7 --> loss = 0.6731310654799143
# Epoch 6: model accuracy 83.56%
# Epoch 8 --> loss = 0.5905525930086771
# Epoch 7: model accuracy 84.84%
# Epoch 9 --> loss = 0.5366564542531967
# Epoch 8: model accuracy 85.96%
# Epoch 10 --> loss = 0.49767450816631315
# Epoch 9: model accuracy 86.69%
# Epoch 11 --> loss = 0.4673740185101827
# Epoch 10: model accuracy 87.31%
# Epoch 12 --> loss = 0.44282380005518596
# Epoch 11: model accuracy 88.02%
# Epoch 13 --> loss = 0.4226394650101662
# Epoch 12: model accuracy 88.70%
# Epoch 14 --> loss = 0.4055377941846848
# Epoch 13: model accuracy 89.10%
# Epoch 15 --> loss = 0.3911489161014557
# Epoch 14: model accuracy 89.53%
# Epoch 16 --> loss = 0.37855836952527366
# Epoch 15: model accuracy 89.80%
# Epoch 17 --> loss = 0.36774858072598776
# Epoch 16: model accuracy 90.11%
# Epoch 18 --> loss = 0.35796428052981694
# Epoch 17: model accuracy 90.34%
# Epoch 19 --> loss = 0.34956220321853954
# Epoch 18: model accuracy 90.60%
# Epoch 20 --> loss = 0.34181173824469246
# Epoch 19: model accuracy 90.84%
# Epoch 1 --> loss = 2.297033915387542
# Epoch 0: model accuracy 16.56%
# Epoch 2 --> loss = 2.263926072161335
# Epoch 1: model accuracy 22.21%
# Epoch 3 --> loss = 2.216619606973774
# Epoch 2: model accuracy 28.57%
# Epoch 4 --> loss = 2.143753536474476
# Epoch 3: model accuracy 38.84%
# Epoch 5 --> loss = 2.0303901147994914
# Epoch 4: model accuracy 51.32%
# Epoch 6 --> loss = 1.8628527236137309
# Epoch 5: model accuracy 62.52%
# Epoch 7 --> loss = 1.6342965173822985
# Epoch 6: model accuracy 70.21%
# Epoch 8 --> loss = 1.3643132365588695
# Epoch 7: model accuracy 74.39%
# Epoch 9 --> loss = 1.1187392539942442
# Epoch 8: model accuracy 78.16%
# Epoch 10 --> loss = 0.9398493605381899
# Epoch 9: model accuracy 80.35%
# Epoch 11 --> loss = 0.8185816298542755
# Epoch 10: model accuracy 81.69%
# Epoch 12 --> loss = 0.7346110555218227
# Epoch 11: model accuracy 82.69%
# Epoch 13 --> loss = 0.6735463240253392
# Epoch 12: model accuracy 83.74%
# Epoch 14 --> loss = 0.6273434171989274
# Epoch 13: model accuracy 84.47%
# Epoch 15 --> loss = 0.5906972493062904
# Epoch 14: model accuracy 85.13%
# Epoch 16 --> loss = 0.5611524756338551
# Epoch 15: model accuracy 85.69%
# Epoch 17 --> loss = 0.5363103307005185
# Epoch 16: model accuracy 86.21%
# Epoch 18 --> loss = 0.5152519286504941
# Epoch 17: model accuracy 86.74%
# Epoch 19 --> loss = 0.49678075002200567
# Epoch 18: model accuracy 87.25%
# Epoch 20 --> loss = 0.4807629911884316
# Epoch 19: model accuracy 87.43%
# Epoch 1 --> loss = 2.304192199381684
# Epoch 0: model accuracy 11.99%
# Epoch 2 --> loss = 2.29440385598872
# Epoch 1: model accuracy 15.10%
# Epoch 3 --> loss = 2.2843112655794187
# Epoch 2: model accuracy 17.21%
# Epoch 4 --> loss = 2.272794476450125
# Epoch 3: model accuracy 18.82%
# Epoch 5 --> loss = 2.258595594719275
# Epoch 4: model accuracy 19.66%
# Epoch 6 --> loss = 2.240418563773637
# Epoch 5: model accuracy 22.99%
# Epoch 7 --> loss = 2.2172465070224265
# Epoch 6: model accuracy 29.38%
# Epoch 8 --> loss = 2.1877102160504633
# Epoch 7: model accuracy 35.04%
# Epoch 9 --> loss = 2.1498750262677286
# Epoch 8: model accuracy 40.40%
# Epoch 10 --> loss = 2.1013477905981066
# Epoch 9: model accuracy 46.63%
# Epoch 11 --> loss = 2.0390983809794445
# Epoch 10: model accuracy 51.98%
# Epoch 12 --> loss = 1.9603030188505584
# Epoch 11: model accuracy 54.94%
# Epoch 13 --> loss = 1.8638973086119206
# Epoch 12: model accuracy 56.81%
# Epoch 14 --> loss = 1.7525525990325506
# Epoch 13: model accuracy 59.10%
# Epoch 15 --> loss = 1.6342124994883913
# Epoch 14: model accuracy 62.05%
# Epoch 16 --> loss = 1.518679044648274
# Epoch 15: model accuracy 65.62%
# Epoch 17 --> loss = 1.4122134238672155
# Epoch 16: model accuracy 68.53%
# Epoch 18 --> loss = 1.3158155336563013
# Epoch 17: model accuracy 71.16%
# Epoch 19 --> loss = 1.228307014335193
# Epoch 18: model accuracy 73.34%
# Epoch 20 --> loss = 1.1481449695538357
# Epoch 19: model accuracy 75.25%
# Epoch 1 --> loss = 2.273239907582601
# Epoch 0: model accuracy 32.33%
# Epoch 2 --> loss = 2.1557793013890585
# Epoch 1: model accuracy 50.00%
# Epoch 3 --> loss = 1.8503975367863974
# Epoch 2: model accuracy 65.21%
# Epoch 4 --> loss = 1.3422578821818034
# Epoch 3: model accuracy 76.60%
# Epoch 5 --> loss = 0.9309729947884877
# Epoch 4: model accuracy 80.21%
# Epoch 6 --> loss = 0.7205421172777812
# Epoch 5: model accuracy 82.63%
# Epoch 7 --> loss = 0.6092175327777862
# Epoch 6: model accuracy 84.64%
# Epoch 8 --> loss = 0.5414941932678222
# Epoch 7: model accuracy 86.12%
# Epoch 9 --> loss = 0.4961951091448466
# Epoch 8: model accuracy 86.90%
# Epoch 10 --> loss = 0.4636276122887929
# Epoch 9: model accuracy 87.53%
# Epoch 11 --> loss = 0.4390583260377248
# Epoch 10: model accuracy 88.10%
# Epoch 12 --> loss = 0.4195832198818525
# Epoch 11: model accuracy 88.45%
# Epoch 13 --> loss = 0.4037155112584432
# Epoch 12: model accuracy 88.77%
# Epoch 14 --> loss = 0.3904226639787356
# Epoch 13: model accuracy 89.29%
# Epoch 15 --> loss = 0.37906609795490903
# Epoch 14: model accuracy 89.49%
# Epoch 16 --> loss = 0.3690675669511159
# Epoch 15: model accuracy 89.77%
# Epoch 17 --> loss = 0.36020607235829033
# Epoch 16: model accuracy 90.07%
# Epoch 18 --> loss = 0.3520223895907402
# Epoch 17: model accuracy 90.33%
# Epoch 19 --> loss = 0.34475975321133934
# Epoch 18: model accuracy 90.35%
# Epoch 20 --> loss = 0.3380905750950178
# Epoch 19: model accuracy 90.63%
# Epoch 1 --> loss = 2.291162745784849
# Epoch 0: model accuracy 22.60%
# Epoch 2 --> loss = 2.2622290448085076
# Epoch 1: model accuracy 33.12%
# Epoch 3 --> loss = 2.2152662185717746
# Epoch 2: model accuracy 39.94%
# Epoch 4 --> loss = 2.137912793962686
# Epoch 3: model accuracy 48.97%
# Epoch 5 --> loss = 2.0165619111772792
# Epoch 4: model accuracy 56.61%
# Epoch 6 --> loss = 1.84277708405879
# Epoch 5: model accuracy 63.66%
# Epoch 7 --> loss = 1.6145647414711748
# Epoch 6: model accuracy 69.05%
# Epoch 8 --> loss = 1.3568844891814535
# Epoch 7: model accuracy 73.53%
# Epoch 9 --> loss = 1.1197358704070801
# Epoch 8: model accuracy 77.09%
# Epoch 10 --> loss = 0.9379092310664496
# Epoch 9: model accuracy 79.77%
# Epoch 11 --> loss = 0.8105095852412649
# Epoch 10: model accuracy 81.63%
# Epoch 12 --> loss = 0.7211021882003305
# Epoch 11: model accuracy 82.98%
# Epoch 13 --> loss = 0.6557412823952083
# Epoch 12: model accuracy 84.07%
# Epoch 14 --> loss = 0.6060930491129218
# Epoch 13: model accuracy 84.88%
# Epoch 15 --> loss = 0.5675250058616402
# Epoch 14: model accuracy 85.66%
# Epoch 16 --> loss = 0.5364025645355172
# Epoch 15: model accuracy 86.17%
# Epoch 17 --> loss = 0.5105997253455588
# Epoch 16: model accuracy 86.93%
# Epoch 18 --> loss = 0.48927853693331735
# Epoch 17: model accuracy 87.37%
# Epoch 19 --> loss = 0.47105055505723586
# Epoch 18: model accuracy 87.69%
# Epoch 20 --> loss = 0.45542258623121645
# Epoch 19: model accuracy 88.07%
# Epoch 1 --> loss = 2.299859009826107
# Epoch 0: model accuracy 16.55%
# Epoch 2 --> loss = 2.285024748173858
# Epoch 1: model accuracy 19.15%
# Epoch 3 --> loss = 2.268804029615195
# Epoch 2: model accuracy 26.80%
# Epoch 4 --> loss = 2.249722643447583
# Epoch 3: model accuracy 36.70%
# Epoch 5 --> loss = 2.2258081349736845
# Epoch 4: model accuracy 46.63%
# Epoch 6 --> loss = 2.1954291258285297
# Epoch 5: model accuracy 54.67%
# Epoch 7 --> loss = 2.1564055327921787
# Epoch 6: model accuracy 59.82%
# Epoch 8 --> loss = 2.105469807887128
# Epoch 7: model accuracy 61.98%
# Epoch 9 --> loss = 2.039375580450111
# Epoch 8: model accuracy 63.41%
# Epoch 10 --> loss = 1.9563618456122718
# Epoch 9: model accuracy 64.95%
# Epoch 11 --> loss = 1.8560811657387057
# Epoch 10: model accuracy 66.84%
# Epoch 12 --> loss = 1.7405782925294662
# Epoch 11: model accuracy 68.52%
# Epoch 13 --> loss = 1.6137633880318354
# Epoch 12: model accuracy 70.31%
# Epoch 14 --> loss = 1.4810887270136428
# Epoch 13: model accuracy 72.15%
# Epoch 15 --> loss = 1.3491331000826252
# Epoch 14: model accuracy 73.96%
# Epoch 16 --> loss = 1.2248860671321975
# Epoch 15: model accuracy 75.70%
# Epoch 17 --> loss = 1.11395012061479
# Epoch 16: model accuracy 77.37%
# Epoch 18 --> loss = 1.018592540516274
# Epoch 17: model accuracy 78.78%
# Epoch 19 --> loss = 0.9381887363726651
# Epoch 18: model accuracy 79.72%
# Epoch 20 --> loss = 0.8708272123895983
# Epoch 19: model accuracy 80.67%
# Epoch 1 --> loss = 2.302545000330607
# Epoch 0: model accuracy 14.50%
# Epoch 2 --> loss = 2.2896431537628175
# Epoch 1: model accuracy 29.69%
# Epoch 3 --> loss = 2.269555882136027
# Epoch 2: model accuracy 43.75%
# Epoch 4 --> loss = 2.2287056957244875
# Epoch 3: model accuracy 44.87%
# Epoch 5 --> loss = 2.1215711086908975
# Epoch 4: model accuracy 37.73%
# Epoch 6 --> loss = 1.875977258237203
# Epoch 5: model accuracy 52.94%
# Epoch 7 --> loss = 1.4533124696095785
# Epoch 6: model accuracy 68.66%
# Epoch 8 --> loss = 0.9975798598925273
# Epoch 7: model accuracy 77.48%
# Epoch 9 --> loss = 0.7612283637841543
# Epoch 8: model accuracy 80.37%
# Epoch 10 --> loss = 0.6493002357403437
# Epoch 9: model accuracy 82.54%
# Epoch 11 --> loss = 0.5791658248504002
# Epoch 10: model accuracy 83.96%
# Epoch 12 --> loss = 0.5291610465367635
# Epoch 11: model accuracy 85.33%
# Epoch 13 --> loss = 0.4929672485907873
# Epoch 12: model accuracy 86.49%
# Epoch 14 --> loss = 0.4661313760916392
# Epoch 13: model accuracy 87.19%
# Epoch 15 --> loss = 0.44514103106657665
# Epoch 14: model accuracy 87.56%
# Epoch 16 --> loss = 0.42786600564718247
# Epoch 15: model accuracy 88.12%
# Epoch 17 --> loss = 0.41300779563188555
# Epoch 16: model accuracy 88.60%
# Epoch 18 --> loss = 0.39978466809590657
# Epoch 17: model accuracy 88.89%
# Epoch 19 --> loss = 0.38767487748066587
# Epoch 18: model accuracy 89.26%
# Epoch 20 --> loss = 0.3766867836475372
# Epoch 19: model accuracy 89.40%
# Epoch 1 --> loss = 2.30228248028867
# Epoch 0: model accuracy 10.52%
# Epoch 2 --> loss = 2.2974919723803553
# Epoch 1: model accuracy 10.45%
# Epoch 3 --> loss = 2.2921717260946344
# Epoch 2: model accuracy 10.60%
# Epoch 4 --> loss = 2.285780126860401
# Epoch 3: model accuracy 16.26%
# Epoch 5 --> loss = 2.277817199479288
# Epoch 4: model accuracy 21.78%
# Epoch 6 --> loss = 2.2673287894934226
# Epoch 5: model accuracy 27.75%
# Epoch 7 --> loss = 2.2528437973339677
# Epoch 6: model accuracy 35.72%
# Epoch 8 --> loss = 2.2319656707076376
# Epoch 7: model accuracy 42.42%
# Epoch 9 --> loss = 2.1997098574506193
# Epoch 8: model accuracy 47.49%
# Epoch 10 --> loss = 2.1455210302430174
# Epoch 9: model accuracy 48.75%
# Epoch 11 --> loss = 2.0537214792613536
# Epoch 10: model accuracy 47.25%
# Epoch 12 --> loss = 1.912574121565707
# Epoch 11: model accuracy 50.00%
# Epoch 13 --> loss = 1.7271624324418335
# Epoch 12: model accuracy 59.17%
# Epoch 14 --> loss = 1.4960882398111226
# Epoch 13: model accuracy 70.37%
# Epoch 15 --> loss = 1.2326374993776716
# Epoch 14: model accuracy 76.83%
# Epoch 16 --> loss = 0.9987305897131149
# Epoch 15: model accuracy 80.26%
# Epoch 17 --> loss = 0.8306762581822206
# Epoch 16: model accuracy 82.36%
# Epoch 18 --> loss = 0.7180296966452588
# Epoch 17: model accuracy 83.68%
# Epoch 19 --> loss = 0.6412394148772205
# Epoch 18: model accuracy 84.68%
# Epoch 20 --> loss = 0.5871131406791175
# Epoch 19: model accuracy 85.39%
# Epoch 1 --> loss = 2.3036020798469656
# Epoch 0: model accuracy 9.78%
# Epoch 2 --> loss = 2.3006530779002827
# Epoch 1: model accuracy 9.79%
# Epoch 3 --> loss = 2.297547126375536
# Epoch 2: model accuracy 9.80%
# Epoch 4 --> loss = 2.2942579311094304
# Epoch 3: model accuracy 9.83%
# Epoch 5 --> loss = 2.2908038172894702
# Epoch 4: model accuracy 10.28%
# Epoch 6 --> loss = 2.287090888663904
# Epoch 5: model accuracy 17.61%
# Epoch 7 --> loss = 2.2829983452998244
# Epoch 6: model accuracy 26.39%
# Epoch 8 --> loss = 2.2784080149522468
# Epoch 7: model accuracy 32.68%
# Epoch 9 --> loss = 2.2730958070327985
# Epoch 8: model accuracy 40.03%
# Epoch 10 --> loss = 2.2668166460513053
# Epoch 9: model accuracy 45.98%
# Epoch 11 --> loss = 2.2592433551227105
# Epoch 10: model accuracy 49.06%
# Epoch 12 --> loss = 2.2501614017527243
# Epoch 11: model accuracy 50.11%
# Epoch 13 --> loss = 2.239218217223438
# Epoch 12: model accuracy 50.11%
# Epoch 14 --> loss = 2.225787988857928
# Epoch 13: model accuracy 49.80%
# Epoch 15 --> loss = 2.209019729577656
# Epoch 14: model accuracy 49.18%
# Epoch 16 --> loss = 2.187776891915783
# Epoch 15: model accuracy 48.53%
# Epoch 17 --> loss = 2.1606206034800644
# Epoch 16: model accuracy 47.83%
# Epoch 18 --> loss = 2.1256958131851165
# Epoch 17: model accuracy 47.59%
# Epoch 19 --> loss = 2.0807381695521667
# Epoch 18: model accuracy 48.03%
# Epoch 20 --> loss = 2.023072246803658
# Epoch 19: model accuracy 48.93%
# Epoch 1 --> loss = 2.2833844418843587
# Epoch 0: model accuracy 26.52%
# Epoch 2 --> loss = 2.1872493229548136
# Epoch 1: model accuracy 40.06%
# Epoch 3 --> loss = 1.9735766825358072
# Epoch 2: model accuracy 59.75%
# Epoch 4 --> loss = 1.5941314915974936
# Epoch 3: model accuracy 71.30%
# Epoch 5 --> loss = 1.1405703098932902
# Epoch 4: model accuracy 77.70%
# Epoch 6 --> loss = 0.8450070367654164
# Epoch 5: model accuracy 81.08%
# Epoch 7 --> loss = 0.6925024765491485
# Epoch 6: model accuracy 83.53%
# Epoch 8 --> loss = 0.6041615920066834
# Epoch 7: model accuracy 84.86%
# Epoch 9 --> loss = 0.5456280450900396
# Epoch 8: model accuracy 85.98%
# Epoch 10 --> loss = 0.503663594341278
# Epoch 9: model accuracy 86.90%
# Epoch 11 --> loss = 0.47189239715735115
# Epoch 10: model accuracy 87.52%
# Epoch 12 --> loss = 0.44696138877073927
# Epoch 11: model accuracy 88.12%
# Epoch 13 --> loss = 0.4268787668744723
# Epoch 12: model accuracy 88.61%
# Epoch 14 --> loss = 0.41031963959932327
# Epoch 13: model accuracy 88.99%
# Epoch 15 --> loss = 0.3962415378451347
# Epoch 14: model accuracy 89.25%
# Epoch 16 --> loss = 0.38422755707105
# Epoch 15: model accuracy 89.40%
# Epoch 17 --> loss = 0.37366954892079035
# Epoch 16: model accuracy 89.66%
# Epoch 18 --> loss = 0.3643462684194247
# Epoch 17: model accuracy 89.88%
# Epoch 19 --> loss = 0.3559451037168503
# Epoch 18: model accuracy 90.18%
# Epoch 20 --> loss = 0.34838922924200694
# Epoch 19: model accuracy 90.22%
# Epoch 1 --> loss = 2.2953062103247084
# Epoch 0: model accuracy 12.40%
# Epoch 2 --> loss = 2.26228669889446
# Epoch 1: model accuracy 25.39%
# Epoch 3 --> loss = 2.2089064499970945
# Epoch 2: model accuracy 43.37%
# Epoch 4 --> loss = 2.120859524588595
# Epoch 3: model accuracy 48.83%
# Epoch 5 --> loss = 1.985118818816854
# Epoch 4: model accuracy 56.06%
# Epoch 6 --> loss = 1.798987967627389
# Epoch 5: model accuracy 60.24%
# Epoch 7 --> loss = 1.5845027061413601
# Epoch 6: model accuracy 64.27%
# Epoch 8 --> loss = 1.3731572797049338
# Epoch 7: model accuracy 69.34%
# Epoch 9 --> loss = 1.1855363444860048
# Epoch 8: model accuracy 74.32%
# Epoch 10 --> loss = 1.0224576703012624
# Epoch 9: model accuracy 77.42%
# Epoch 11 --> loss = 0.8858737927128766
# Epoch 10: model accuracy 79.99%
# Epoch 12 --> loss = 0.7798035730049808
# Epoch 11: model accuracy 81.84%
# Epoch 13 --> loss = 0.700288935701476
# Epoch 12: model accuracy 83.52%
# Epoch 14 --> loss = 0.6407831448799511
# Epoch 13: model accuracy 84.52%
# Epoch 15 --> loss = 0.5949030934112158
# Epoch 14: model accuracy 85.26%
# Epoch 16 --> loss = 0.5592023185384807
# Epoch 15: model accuracy 85.90%
# Epoch 17 --> loss = 0.5300662632245244
# Epoch 16: model accuracy 86.42%
# Epoch 18 --> loss = 0.506735066122719
# Epoch 17: model accuracy 86.86%
# Epoch 19 --> loss = 0.48728363411322334
# Epoch 18: model accuracy 87.16%
# Epoch 20 --> loss = 0.4708546260431377
# Epoch 19: model accuracy 87.48%
# Epoch 1 --> loss = 2.3014149193062203
# Epoch 0: model accuracy 8.97%
# Epoch 2 --> loss = 2.2857284718739197
# Epoch 1: model accuracy 11.93%
# Epoch 3 --> loss = 2.268705549016436
# Epoch 2: model accuracy 16.11%
# Epoch 4 --> loss = 2.248698157288118
# Epoch 3: model accuracy 22.77%
# Epoch 5 --> loss = 2.224121201012943
# Epoch 4: model accuracy 25.46%
# Epoch 6 --> loss = 2.1932400803067793
# Epoch 5: model accuracy 27.31%
# Epoch 7 --> loss = 2.1541590126338543
# Epoch 6: model accuracy 36.92%
# Epoch 8 --> loss = 2.105571492140227
# Epoch 7: model accuracy 44.72%
# Epoch 9 --> loss = 2.0468364532059953
# Epoch 8: model accuracy 49.29%
# Epoch 10 --> loss = 1.9773207130208452
# Epoch 9: model accuracy 52.84%
# Epoch 11 --> loss = 1.896367801532054
# Epoch 10: model accuracy 56.01%
# Epoch 12 --> loss = 1.8030201067039962
# Epoch 11: model accuracy 59.01%
# Epoch 13 --> loss = 1.696741807435367
# Epoch 12: model accuracy 61.92%
# Epoch 14 --> loss = 1.579603951877114
# Epoch 13: model accuracy 64.79%
# Epoch 15 --> loss = 1.4568133092384095
# Epoch 14: model accuracy 67.88%
# Epoch 16 --> loss = 1.334896157799499
# Epoch 15: model accuracy 71.42%
# Epoch 17 --> loss = 1.2198477454785346
# Epoch 16: model accuracy 73.83%
# Epoch 18 --> loss = 1.1158953042172675
# Epoch 17: model accuracy 75.44%
# Epoch 19 --> loss = 1.0251684817932307
# Epoch 18: model accuracy 76.86%
# Epoch 20 --> loss = 0.9479104032648652
# Epoch 19: model accuracy 77.93%
# Epoch 1 --> loss = 1.1410621988693872
# Epoch 0: model accuracy 87.62%
# Epoch 2 --> loss = 0.37854640837907794
# Epoch 1: model accuracy 90.70%
# Epoch 3 --> loss = 0.3098006747643153
# Epoch 2: model accuracy 92.16%
# Epoch 4 --> loss = 0.2708617802639802
# Epoch 3: model accuracy 92.85%
# Epoch 5 --> loss = 0.2405727329572042
# Epoch 4: model accuracy 93.63%
# Epoch 6 --> loss = 0.21494375241001448
# Epoch 5: model accuracy 94.05%
# Epoch 7 --> loss = 0.19387808588147162
# Epoch 6: model accuracy 94.66%
# Epoch 8 --> loss = 0.17625725797514122
# Epoch 7: model accuracy 94.99%
# Epoch 9 --> loss = 0.16111578063915175
# Epoch 8: model accuracy 95.30%
# Epoch 10 --> loss = 0.1479943620716532
# Epoch 9: model accuracy 95.66%
# Epoch 11 --> loss = 0.13676230423152447
# Epoch 10: model accuracy 96.03%
# Epoch 12 --> loss = 0.12693120990470053
# Epoch 11: model accuracy 96.30%
# Epoch 13 --> loss = 0.1177435316455861
# Epoch 12: model accuracy 96.32%
# Epoch 14 --> loss = 0.11024095722089211
# Epoch 13: model accuracy 96.51%
# Epoch 15 --> loss = 0.10290537815963229
# Epoch 14: model accuracy 96.77%
# Epoch 16 --> loss = 0.09682288574750225
# Epoch 15: model accuracy 97.01%
# Epoch 17 --> loss = 0.09123775982136528
# Epoch 16: model accuracy 97.00%
# Epoch 18 --> loss = 0.085889336707443
# Epoch 17: model accuracy 97.07%
# Epoch 19 --> loss = 0.0811510479165862
# Epoch 18: model accuracy 97.12%
# Epoch 20 --> loss = 0.07668685037444035
# Epoch 19: model accuracy 97.17%
# Epoch 1 --> loss = 1.821150240232187
# Epoch 0: model accuracy 79.76%
# Epoch 2 --> loss = 0.6018573390458947
# Epoch 1: model accuracy 88.16%
# Epoch 3 --> loss = 0.4014943355499809
# Epoch 2: model accuracy 90.11%
# Epoch 4 --> loss = 0.3454424082152625
# Epoch 3: model accuracy 91.17%
# Epoch 5 --> loss = 0.31407255744501983
# Epoch 4: model accuracy 91.75%
# Epoch 6 --> loss = 0.29107082405610124
# Epoch 5: model accuracy 92.33%
# Epoch 7 --> loss = 0.27210239656984425
# Epoch 6: model accuracy 92.78%
# Epoch 8 --> loss = 0.2555442582418733
# Epoch 7: model accuracy 93.19%
# Epoch 9 --> loss = 0.2403777582225388
# Epoch 8: model accuracy 93.42%
# Epoch 10 --> loss = 0.22650968604314048
# Epoch 9: model accuracy 93.96%
# Epoch 11 --> loss = 0.21363445379332438
# Epoch 10: model accuracy 93.97%
# Epoch 12 --> loss = 0.2024410421739636
# Epoch 11: model accuracy 94.33%
# Epoch 13 --> loss = 0.19181945791114557
# Epoch 12: model accuracy 94.59%
# Epoch 14 --> loss = 0.18165398666313462
# Epoch 13: model accuracy 94.77%
# Epoch 15 --> loss = 0.17300132555025283
# Epoch 14: model accuracy 95.06%
# Epoch 16 --> loss = 0.1645609733424207
# Epoch 15: model accuracy 95.17%
# Epoch 17 --> loss = 0.15708009953072458
# Epoch 16: model accuracy 95.46%
# Epoch 18 --> loss = 0.15004564118958802
# Epoch 17: model accuracy 95.60%
# Epoch 19 --> loss = 0.14333042363201315
# Epoch 18: model accuracy 95.75%
# Epoch 20 --> loss = 0.13718113943791466
# Epoch 19: model accuracy 95.63%
# Epoch 1 --> loss = 2.2119336852640994
# Epoch 0: model accuracy 54.53%
# Epoch 2 --> loss = 1.4440366886317857
# Epoch 1: model accuracy 80.78%
# Epoch 3 --> loss = 0.6821715484804182
# Epoch 2: model accuracy 85.51%
# Epoch 4 --> loss = 0.4979582305656059
# Epoch 3: model accuracy 87.57%
# Epoch 5 --> loss = 0.4292173749729514
# Epoch 4: model accuracy 88.85%
# Epoch 6 --> loss = 0.3895581652805495
# Epoch 5: model accuracy 89.84%
# Epoch 7 --> loss = 0.3621615075162733
# Epoch 6: model accuracy 90.30%
# Epoch 8 --> loss = 0.341594269789104
# Epoch 7: model accuracy 90.96%
# Epoch 9 --> loss = 0.3249106193020908
# Epoch 8: model accuracy 91.27%
# Epoch 10 --> loss = 0.3109325917799081
# Epoch 9: model accuracy 91.68%
# Epoch 11 --> loss = 0.2985631430199914
# Epoch 10: model accuracy 91.93%
# Epoch 12 --> loss = 0.28797863311033006
# Epoch 11: model accuracy 92.34%
# Epoch 13 --> loss = 0.2781212457271019
# Epoch 12: model accuracy 92.68%
# Epoch 14 --> loss = 0.2689252520548001
# Epoch 13: model accuracy 92.90%
# Epoch 15 --> loss = 0.2603867454791882
# Epoch 14: model accuracy 93.07%
# Epoch 16 --> loss = 0.2526168541105063
# Epoch 15: model accuracy 93.23%
# Epoch 17 --> loss = 0.24493691077364532
# Epoch 16: model accuracy 93.43%
# Epoch 18 --> loss = 0.23791436614321748
# Epoch 17: model accuracy 93.52%
# Epoch 19 --> loss = 0.23159831195180094
# Epoch 18: model accuracy 93.66%
# Epoch 20 --> loss = 0.22496044151246675
# Epoch 19: model accuracy 93.83%
# Epoch 1 --> loss = 1.6252691948572795
# Epoch 0: model accuracy 82.91%
# Epoch 2 --> loss = 0.4404122561534246
# Epoch 1: model accuracy 90.00%
# Epoch 3 --> loss = 0.3252126923918724
# Epoch 2: model accuracy 91.65%
# Epoch 4 --> loss = 0.27031320804059505
# Epoch 3: model accuracy 93.04%
# Epoch 5 --> loss = 0.22527661006649335
# Epoch 4: model accuracy 94.06%
# Epoch 6 --> loss = 0.1893187602698803
# Epoch 5: model accuracy 94.93%
# Epoch 7 --> loss = 0.16249591916451853
# Epoch 6: model accuracy 95.45%
# Epoch 8 --> loss = 0.14017176098575196
# Epoch 7: model accuracy 96.07%
# Epoch 9 --> loss = 0.12379060941686233
# Epoch 8: model accuracy 96.24%
# Epoch 10 --> loss = 0.10981418579717477
# Epoch 9: model accuracy 96.40%
# Epoch 11 --> loss = 0.09792379283967118
# Epoch 10: model accuracy 96.49%
# Epoch 12 --> loss = 0.0885010813763986
# Epoch 11: model accuracy 96.76%
# Epoch 13 --> loss = 0.08002977040993671
# Epoch 12: model accuracy 97.13%
# Epoch 14 --> loss = 0.07284337099182109
# Epoch 13: model accuracy 97.03%
# Epoch 15 --> loss = 0.0660238916678975
# Epoch 14: model accuracy 97.16%
# Epoch 16 --> loss = 0.06045940406943361
# Epoch 15: model accuracy 97.07%
# Epoch 17 --> loss = 0.055536133349034934
# Epoch 16: model accuracy 97.33%
# Epoch 18 --> loss = 0.05095420163640132
# Epoch 17: model accuracy 97.28%
# Epoch 19 --> loss = 0.04695653997479628
# Epoch 18: model accuracy 97.41%
# Epoch 20 --> loss = 0.042487929226706425
# Epoch 19: model accuracy 97.53%
# Epoch 1 --> loss = 2.2239595546142885
# Epoch 0: model accuracy 46.21%
# Epoch 2 --> loss = 1.0540632962354466
# Epoch 1: model accuracy 81.78%
# Epoch 3 --> loss = 0.505936203544328
# Epoch 2: model accuracy 87.88%
# Epoch 4 --> loss = 0.38632881669982916
# Epoch 3: model accuracy 89.84%
# Epoch 5 --> loss = 0.3357129196193554
# Epoch 4: model accuracy 90.86%
# Epoch 6 --> loss = 0.3024285394134425
# Epoch 5: model accuracy 91.78%
# Epoch 7 --> loss = 0.27444813580814204
# Epoch 6: model accuracy 92.86%
# Epoch 8 --> loss = 0.24867885398156225
# Epoch 7: model accuracy 93.40%
# Epoch 9 --> loss = 0.22574844342797423
# Epoch 8: model accuracy 93.93%
# Epoch 10 --> loss = 0.20547263360004436
# Epoch 9: model accuracy 94.31%
# Epoch 11 --> loss = 0.18830034728132206
# Epoch 10: model accuracy 94.88%
# Epoch 12 --> loss = 0.17382503154753112
# Epoch 11: model accuracy 95.28%
# Epoch 13 --> loss = 0.1605145494753459
# Epoch 12: model accuracy 95.51%
# Epoch 14 --> loss = 0.14890530624830012
# Epoch 13: model accuracy 95.54%
# Epoch 15 --> loss = 0.1388317763801418
# Epoch 14: model accuracy 95.90%
# Epoch 16 --> loss = 0.12980944712036677
# Epoch 15: model accuracy 96.05%
# Epoch 17 --> loss = 0.12161320745488251
# Epoch 16: model accuracy 96.21%
# Epoch 18 --> loss = 0.11402523477694818
# Epoch 17: model accuracy 96.52%
# Epoch 19 --> loss = 0.10702052106385801
# Epoch 18: model accuracy 96.64%
# Epoch 20 --> loss = 0.10076295054936682
# Epoch 19: model accuracy 96.69%
# Epoch 1 --> loss = 2.2787651964850517
# Epoch 0: model accuracy 32.99%
# Epoch 2 --> loss = 2.064607167548971
# Epoch 1: model accuracy 52.10%
# Epoch 3 --> loss = 1.1659757604222816
# Epoch 2: model accuracy 77.48%
# Epoch 4 --> loss = 0.6655496580005963
# Epoch 3: model accuracy 83.51%
# Epoch 5 --> loss = 0.5288006189281244
# Epoch 4: model accuracy 86.34%
# Epoch 6 --> loss = 0.45385512966972424
# Epoch 5: model accuracy 87.86%
# Epoch 7 --> loss = 0.40955654336318276
# Epoch 6: model accuracy 88.82%
# Epoch 8 --> loss = 0.3777526595445076
# Epoch 7: model accuracy 89.62%
# Epoch 9 --> loss = 0.35326289457044624
# Epoch 8: model accuracy 90.25%
# Epoch 10 --> loss = 0.33191057264423574
# Epoch 9: model accuracy 90.79%
# Epoch 11 --> loss = 0.31375569845440543
# Epoch 10: model accuracy 91.21%
# Epoch 12 --> loss = 0.2974130171003626
# Epoch 11: model accuracy 91.81%
# Epoch 13 --> loss = 0.28201958549810624
# Epoch 12: model accuracy 92.17%
# Epoch 14 --> loss = 0.2676283651704727
# Epoch 13: model accuracy 92.76%
# Epoch 15 --> loss = 0.2537938797397654
# Epoch 14: model accuracy 93.05%
# Epoch 16 --> loss = 0.24029170888573376
# Epoch 15: model accuracy 93.31%
# Epoch 17 --> loss = 0.22825815380890485
# Epoch 16: model accuracy 93.69%
# Epoch 18 --> loss = 0.21646934279055993
# Epoch 17: model accuracy 93.81%
# Epoch 19 --> loss = 0.20567302245384594
# Epoch 18: model accuracy 94.40%
# Epoch 20 --> loss = 0.19602787723419254
# Epoch 19: model accuracy 94.56%
# Epoch 1 --> loss = 1.2776542278448741
# Epoch 0: model accuracy 86.79%
# Epoch 2 --> loss = 0.4081126261870066
# Epoch 1: model accuracy 90.01%
# Epoch 3 --> loss = 0.32837331075867016
# Epoch 2: model accuracy 91.31%
# Epoch 4 --> loss = 0.286877954591314
# Epoch 3: model accuracy 92.27%
# Epoch 5 --> loss = 0.2550842513412237
# Epoch 4: model accuracy 93.04%
# Epoch 6 --> loss = 0.22879930173357327
# Epoch 5: model accuracy 93.64%
# Epoch 7 --> loss = 0.20757192148466905
# Epoch 6: model accuracy 94.17%
# Epoch 8 --> loss = 0.18877976423154275
# Epoch 7: model accuracy 94.53%
# Epoch 9 --> loss = 0.17357813379367193
# Epoch 8: model accuracy 95.06%
# Epoch 10 --> loss = 0.16038097531199455
# Epoch 9: model accuracy 95.18%
# Epoch 11 --> loss = 0.14936903324127196
# Epoch 10: model accuracy 95.48%
# Epoch 12 --> loss = 0.1391408563762903
# Epoch 11: model accuracy 95.74%
# Epoch 13 --> loss = 0.13027483432764808
# Epoch 12: model accuracy 95.86%
# Epoch 14 --> loss = 0.12266026305456956
# Epoch 13: model accuracy 96.04%
# Epoch 15 --> loss = 0.1162208308575054
# Epoch 14: model accuracy 96.22%
# Epoch 16 --> loss = 0.10992035562694073
# Epoch 15: model accuracy 96.37%
# Epoch 17 --> loss = 0.10466664801190297
# Epoch 16: model accuracy 96.50%
# Epoch 18 --> loss = 0.09935986131529013
# Epoch 17: model accuracy 96.57%
# Epoch 19 --> loss = 0.09468763698997597
# Epoch 18: model accuracy 96.65%
# Epoch 20 --> loss = 0.09034530998890598
# Epoch 19: model accuracy 96.72%
# Epoch 1 --> loss = 1.7597399765748714
# Epoch 0: model accuracy 80.95%
# Epoch 2 --> loss = 0.5721886887638046
# Epoch 1: model accuracy 87.99%
# Epoch 3 --> loss = 0.4052580071251784
# Epoch 2: model accuracy 89.54%
# Epoch 4 --> loss = 0.3560279158116785
# Epoch 3: model accuracy 90.55%
# Epoch 5 --> loss = 0.32796154226829755
# Epoch 4: model accuracy 91.02%
# Epoch 6 --> loss = 0.30655043227459067
# ...
# Epoch 19 --> loss = 0.013358926972723324
# Epoch 18: model accuracy 97.52%
# Epoch 20 --> loss = 0.013790511586996582
# Epoch 19: model accuracy 97.45%
# Epoch 1 --> loss = 0.545921266078949
# Epoch 0: model accuracy 91.85%
# Epoch 2 --> loss = 0.20764804764120565
# Epoch 1: model accuracy 94.80%
# Epoch 3 --> loss = 0.1463131402144586
# Epoch 2: model accuracy 95.95%
# Epoch 4 --> loss = 0.11463660692700794
# Epoch 3: model accuracy 95.72%
# Epoch 5 --> loss = 0.09587901677322715
# Epoch 4: model accuracy 96.03%
# Epoch 6 --> loss = 0.08183142676629793
# Epoch 5: model accuracy 96.95%
# Epoch 7 --> loss = 0.07101103411848421
# Epoch 6: model accuracy 96.50%
# Epoch 8 --> loss = 0.06265341413682943
# Epoch 7: model accuracy 97.17%
# Epoch 9 --> loss = 0.05678650706848586
# Epoch 8: model accuracy 97.04%
# Epoch 10 --> loss = 0.050342815583631365
# Epoch 9: model accuracy 97.32%
# Epoch 11 --> loss = 0.044850713663251954
# Epoch 10: model accuracy 97.38%
# Epoch 12 --> loss = 0.041026984613864365
# Epoch 11: model accuracy 97.44%
# Epoch 13 --> loss = 0.036159255187278354
# Epoch 12: model accuracy 97.19%
# Epoch 14 --> loss = 0.032937118134745307
# Epoch 13: model accuracy 97.39%
# Epoch 15 --> loss = 0.029809492818047123
# Epoch 14: model accuracy 97.52%
# Epoch 16 --> loss = 0.02687961464768389
# Epoch 15: model accuracy 97.01%
# Epoch 17 --> loss = 0.023737874369622013
# Epoch 16: model accuracy 97.39%
# Epoch 18 --> loss = 0.02110973793140395
# Epoch 17: model accuracy 97.48%
# Epoch 19 --> loss = 0.019717589577285526
# Epoch 18: model accuracy 97.60%
# Epoch 20 --> loss = 0.016969638990643156
# Epoch 19: model accuracy 97.63%
# Epoch 1 --> loss = 0.7364686061896241
# Epoch 0: model accuracy 91.30%
# Epoch 2 --> loss = 0.28226548921007083
# Epoch 1: model accuracy 93.33%
# Epoch 3 --> loss = 0.21890795726511778
# Epoch 2: model accuracy 94.30%
# Epoch 4 --> loss = 0.17715447899629314
# Epoch 3: model accuracy 95.51%
# Epoch 5 --> loss = 0.14910466792677513
# Epoch 4: model accuracy 95.81%
# Epoch 6 --> loss = 0.12811370646712114
# Epoch 5: model accuracy 96.03%
# Epoch 7 --> loss = 0.11022006198446126
# Epoch 6: model accuracy 96.58%
# Epoch 8 --> loss = 0.09846095589480039
# Epoch 7: model accuracy 96.76%
# Epoch 9 --> loss = 0.0881357676486598
# Epoch 8: model accuracy 97.14%
# Epoch 10 --> loss = 0.07903779478175744
# Epoch 9: model accuracy 96.94%
# Epoch 11 --> loss = 0.07187867246028076
# Epoch 10: model accuracy 97.05%
# Epoch 12 --> loss = 0.0663627393579464
# Epoch 11: model accuracy 97.22%
# Epoch 13 --> loss = 0.061467855130193205
# Epoch 12: model accuracy 97.34%
# Epoch 14 --> loss = 0.05682874510465845
# Epoch 13: model accuracy 97.46%
# Epoch 15 --> loss = 0.052066308915861316
# Epoch 14: model accuracy 97.30%
# Epoch 16 --> loss = 0.04839200253334286
# Epoch 15: model accuracy 97.05%
# Epoch 17 --> loss = 0.04485184518493283
# Epoch 16: model accuracy 97.46%
# Epoch 18 --> loss = 0.04209687765727419
# Epoch 17: model accuracy 97.29%
# Epoch 19 --> loss = 0.03866845657373828
# Epoch 18: model accuracy 97.33%
# Epoch 20 --> loss = 0.03700503840077438
# Epoch 19: model accuracy 97.57%
# Epoch 1 --> loss = 0.370656412712733
# Epoch 0: model accuracy 95.08%
# Epoch 2 --> loss = 0.12955689262996117
# Epoch 1: model accuracy 96.69%
# Epoch 3 --> loss = 0.08816019585765898
# Epoch 2: model accuracy 97.20%
# Epoch 4 --> loss = 0.06787934863554934
# Epoch 3: model accuracy 97.07%
# Epoch 5 --> loss = 0.053949937338754535
# Epoch 4: model accuracy 97.52%
# Epoch 6 --> loss = 0.043491396446091436
# Epoch 5: model accuracy 97.51%
# Epoch 7 --> loss = 0.03618725437068691
# Epoch 6: model accuracy 97.47%
# Epoch 8 --> loss = 0.03033002591833162
# Epoch 7: model accuracy 97.68%
# Epoch 9 --> loss = 0.024214653044077567
# Epoch 8: model accuracy 97.73%
# Epoch 10 --> loss = 0.021087492187251335
# Epoch 9: model accuracy 97.64%
# Epoch 11 --> loss = 0.016517721152042215
# Epoch 10: model accuracy 97.88%
# Epoch 12 --> loss = 0.012653110664642494
# Epoch 11: model accuracy 97.67%
# Epoch 13 --> loss = 0.010593030461797026
# Epoch 12: model accuracy 97.99%
# Epoch 14 --> loss = 0.007666181750744484
# Epoch 13: model accuracy 98.15%
# Epoch 15 --> loss = 0.005995614779513077
# Epoch 14: model accuracy 98.02%
# Epoch 16 --> loss = 0.004899990884276607
# Epoch 15: model accuracy 98.04%
# Epoch 17 --> loss = 0.0035003279989817503
# Epoch 16: model accuracy 98.13%
# Epoch 18 --> loss = 0.002025596193824337
# Epoch 17: model accuracy 98.18%
# Epoch 19 --> loss = 0.0012971236270398246
# Epoch 18: model accuracy 98.22%
# Epoch 20 --> loss = 0.0008396347912887601
# Epoch 19: model accuracy 98.26%
# Epoch 1 --> loss = 0.509446144596473
# Epoch 0: model accuracy 92.92%
# Epoch 2 --> loss = 0.1949318360441974
# Epoch 1: model accuracy 95.02%
# Epoch 3 --> loss = 0.13534084585374162
# Epoch 2: model accuracy 96.08%
# Epoch 4 --> loss = 0.10433331735110454
# Epoch 3: model accuracy 96.90%
# Epoch 5 --> loss = 0.08440940056159012
# Epoch 4: model accuracy 97.20%
# Epoch 6 --> loss = 0.06944369624278494
# Epoch 5: model accuracy 97.15%
# Epoch 7 --> loss = 0.05844002852200477
# Epoch 6: model accuracy 97.62%
# Epoch 8 --> loss = 0.04895085009556613
# Epoch 7: model accuracy 97.70%
# Epoch 9 --> loss = 0.042392564274351806
# Epoch 8: model accuracy 97.76%
# Epoch 10 --> loss = 0.03589430011298531
# Epoch 9: model accuracy 97.64%
# Epoch 11 --> loss = 0.030859274817739864
# Epoch 10: model accuracy 96.75%
# Epoch 12 --> loss = 0.025721924774262356
# Epoch 11: model accuracy 97.83%
# Epoch 13 --> loss = 0.022808130616001957
# Epoch 12: model accuracy 97.48%
# Epoch 14 --> loss = 0.019139560088125576
# Epoch 13: model accuracy 97.92%
# Epoch 15 --> loss = 0.015872535830419976
# Epoch 14: model accuracy 98.05%
# Epoch 16 --> loss = 0.012881297432140622
# Epoch 15: model accuracy 97.97%
# Epoch 17 --> loss = 0.011658759661567292
# Epoch 16: model accuracy 98.02%
# Epoch 18 --> loss = 0.009468346055438082
# Epoch 17: model accuracy 97.96%
# Epoch 19 --> loss = 0.007704364150056495
# Epoch 18: model accuracy 98.05%
# Epoch 20 --> loss = 0.006500683565321105
# Epoch 19: model accuracy 97.86%
# Epoch 1 --> loss = 0.6779837383707957
# Epoch 0: model accuracy 91.47%
# Epoch 2 --> loss = 0.27146683803308747
# Epoch 1: model accuracy 93.20%
# Epoch 3 --> loss = 0.20036913618159446
# Epoch 2: model accuracy 95.04%
# Epoch 4 --> loss = 0.15935085073653568
# Epoch 3: model accuracy 95.73%
# Epoch 5 --> loss = 0.1321753982716659
# Epoch 4: model accuracy 96.12%
# Epoch 6 --> loss = 0.11203541091955038
# Epoch 5: model accuracy 96.53%
# Epoch 7 --> loss = 0.09712991739577576
# Epoch 6: model accuracy 96.96%
# Epoch 8 --> loss = 0.08492600102859266
# Epoch 7: model accuracy 96.84%
# Epoch 9 --> loss = 0.07505785009023477
# Epoch 8: model accuracy 96.88%
# Epoch 10 --> loss = 0.06776661980650954
# Epoch 9: model accuracy 97.33%
# Epoch 11 --> loss = 0.060056251831162075
# Epoch 10: model accuracy 97.45%
# Epoch 12 --> loss = 0.053932538523134205
# Epoch 11: model accuracy 97.50%
# Epoch 13 --> loss = 0.04930067683921567
# Epoch 12: model accuracy 97.53%
# Epoch 14 --> loss = 0.044577171797675494
# Epoch 13: model accuracy 97.62%
# Epoch 15 --> loss = 0.04020206860181238
# Epoch 14: model accuracy 97.37%
# Epoch 16 --> loss = 0.036947694595164456
# Epoch 15: model accuracy 97.72%
# Epoch 17 --> loss = 0.03318342618020708
# Epoch 16: model accuracy 97.82%
# Epoch 18 --> loss = 0.030181205218860398
# Epoch 17: model accuracy 97.63%
# Epoch 19 --> loss = 0.028034512300107842
# Epoch 18: model accuracy 97.62%
# Epoch 20 --> loss = 0.02562896438491052
# Epoch 19: model accuracy 97.86%
# Epoch 1 --> loss = 0.4272285414805015
# Epoch 0: model accuracy 94.97%
# Epoch 2 --> loss = 0.11834633281230926
# Epoch 1: model accuracy 97.21%
# Epoch 3 --> loss = 0.08124201023721446
# Epoch 2: model accuracy 97.52%
# Epoch 4 --> loss = 0.06018600688424582
# Epoch 3: model accuracy 97.63%
# Epoch 5 --> loss = 0.046334886146274706
# Epoch 4: model accuracy 97.66%
# Epoch 6 --> loss = 0.03677436282452351
# Epoch 5: model accuracy 97.93%
# Epoch 7 --> loss = 0.02872296144471038
# Epoch 6: model accuracy 98.01%
# Epoch 8 --> loss = 0.022844489781686572
# Epoch 7: model accuracy 97.85%
# Epoch 9 --> loss = 0.01983940662937336
# Epoch 8: model accuracy 97.87%
# Epoch 10 --> loss = 0.0176592210139308
# Epoch 9: model accuracy 98.01%
# Epoch 11 --> loss = 0.014236621492475872
# Epoch 10: model accuracy 98.10%
# Epoch 12 --> loss = 0.01194299961009577
# Epoch 11: model accuracy 97.73%
# Epoch 13 --> loss = 0.007697723439884552
# Epoch 12: model accuracy 98.21%
# Epoch 14 --> loss = 0.007794329276280708
# Epoch 13: model accuracy 98.14%
# Epoch 15 --> loss = 0.005813472566673075
# Epoch 14: model accuracy 98.15%
# Epoch 16 --> loss = 0.0059313666878304805
# Epoch 15: model accuracy 98.25%
# Epoch 17 --> loss = 0.0074275207012726545
# Epoch 16: model accuracy 98.27%
# Epoch 18 --> loss = 0.00874707271045163
# Epoch 17: model accuracy 97.84%
# Epoch 19 --> loss = 0.002795898335960199
# Epoch 18: model accuracy 98.25%
# Epoch 20 --> loss = 0.0006002263127815884
# Epoch 19: model accuracy 98.32%
# Epoch 1 --> loss = 0.6063382271915547
# Epoch 0: model accuracy 93.03%
# Epoch 2 --> loss = 0.16106513730669295
# Epoch 1: model accuracy 96.00%
# Epoch 3 --> loss = 0.1046648826370679
# Epoch 2: model accuracy 95.75%
# Epoch 4 --> loss = 0.07870872304496813
# Epoch 3: model accuracy 97.12%
# Epoch 5 --> loss = 0.060751544426568646
# Epoch 4: model accuracy 96.90%
# Epoch 6 --> loss = 0.049027664580696156
# Epoch 5: model accuracy 97.44%
# Epoch 7 --> loss = 0.03997987648981041
# Epoch 6: model accuracy 97.58%
# Epoch 8 --> loss = 0.03238683217471944
# Epoch 7: model accuracy 97.13%
# Epoch 9 --> loss = 0.0255448961538498
# Epoch 8: model accuracy 98.12%
# Epoch 10 --> loss = 0.020005937180678442
# Epoch 9: model accuracy 97.96%
# Epoch 11 --> loss = 0.018553073909731883
# Epoch 10: model accuracy 97.90%
# Epoch 12 --> loss = 0.01244276113488137
# Epoch 11: model accuracy 97.99%
# Epoch 13 --> loss = 0.008770059594982995
# Epoch 12: model accuracy 97.98%
# Epoch 14 --> loss = 0.005714775135147298
# Epoch 13: model accuracy 98.17%
# Epoch 15 --> loss = 0.004248161132308868
# Epoch 14: model accuracy 98.20%
# Epoch 16 --> loss = 0.0022772207219004525
# Epoch 15: model accuracy 98.37%
# Epoch 17 --> loss = 0.001494253438358855
# Epoch 16: model accuracy 98.36%
# Epoch 18 --> loss = 0.0010782427186608488
# Epoch 17: model accuracy 98.36%
# Epoch 19 --> loss = 0.001168139554298824
# Epoch 18: model accuracy 98.26%
# Epoch 20 --> loss = 0.0007489880174600876
# Epoch 19: model accuracy 98.27%
# Epoch 1 --> loss = 0.9905332718004805
# Epoch 0: model accuracy 90.11%
# Epoch 2 --> loss = 0.2656893680281222
# Epoch 1: model accuracy 93.62%
# Epoch 3 --> loss = 0.17146854471169046
# Epoch 2: model accuracy 95.86%
# Epoch 4 --> loss = 0.1254707897014455
# Epoch 3: model accuracy 96.61%
# Epoch 5 --> loss = 0.09867641772987491
# Epoch 4: model accuracy 96.89%
# Epoch 6 --> loss = 0.08059717029499919
# Epoch 5: model accuracy 97.27%
# Epoch 7 --> loss = 0.06796617418138394
# Epoch 6: model accuracy 97.37%
# Epoch 8 --> loss = 0.05760411166552224
# Epoch 7: model accuracy 97.44%
# Epoch 9 --> loss = 0.04962115647243475
# Epoch 8: model accuracy 97.18%
# Epoch 10 --> loss = 0.0435717205282674
# Epoch 9: model accuracy 97.63%
# Epoch 11 --> loss = 0.03609953987807321
# Epoch 10: model accuracy 97.03%
# Epoch 12 --> loss = 0.03106976837626716
# Epoch 11: model accuracy 97.15%
# Epoch 13 --> loss = 0.02589126898130692
# Epoch 12: model accuracy 97.91%
# Epoch 14 --> loss = 0.022071991598348755
# Epoch 13: model accuracy 97.91%
# Epoch 15 --> loss = 0.018443840732331327
# Epoch 14: model accuracy 97.96%
# Epoch 16 --> loss = 0.015494202722612618
# Epoch 15: model accuracy 98.01%
# Epoch 17 --> loss = 0.013572379804478446
# Epoch 16: model accuracy 97.92%
# Epoch 18 --> loss = 0.010966093963392372
# Epoch 17: model accuracy 97.98%
# Epoch 19 --> loss = 0.008841505853398672
# Epoch 18: model accuracy 98.01%
# Epoch 20 --> loss = 0.006616292707026322
# Epoch 19: model accuracy 98.03%
# Epoch 1 --> loss = 0.3868265636434158
# Epoch 0: model accuracy 95.33%
# Epoch 2 --> loss = 0.1480312220727404
# Epoch 1: model accuracy 96.62%
# Epoch 3 --> loss = 0.10529950787251194
# Epoch 2: model accuracy 96.52%
# Epoch 4 --> loss = 0.08526693685284505
# Epoch 3: model accuracy 97.28%
# Epoch 5 --> loss = 0.0716913694798636
# Epoch 4: model accuracy 97.20%
# Epoch 6 --> loss = 0.061060136307791495
# Epoch 5: model accuracy 97.37%
# Epoch 7 --> loss = 0.051705555060847355
# Epoch 6: model accuracy 96.94%
# Epoch 8 --> loss = 0.046578451281188364
# Epoch 7: model accuracy 97.31%
# Epoch 9 --> loss = 0.04102313456799214
# Epoch 8: model accuracy 97.66%
# Epoch 10 --> loss = 0.03408549441693661
# Epoch 9: model accuracy 97.40%
# Epoch 11 --> loss = 0.030861188376757005
# Epoch 10: model accuracy 97.57%
# Epoch 12 --> loss = 0.02791466320452746
# Epoch 11: model accuracy 97.20%
# Epoch 13 --> loss = 0.02395579348083896
# Epoch 12: model accuracy 97.52%
# Epoch 14 --> loss = 0.020158367315272336
# Epoch 13: model accuracy 97.10%
# Epoch 15 --> loss = 0.019419693292182637
# Epoch 14: model accuracy 97.39%
# Epoch 16 --> loss = 0.018278491506776483
# Epoch 15: model accuracy 97.38%
# Epoch 17 --> loss = 0.013163816294560092
# Epoch 16: model accuracy 97.54%
# Epoch 18 --> loss = 0.01149566819653143
# Epoch 17: model accuracy 97.60%
# Epoch 19 --> loss = 0.012435219105447079
# Epoch 18: model accuracy 97.74%
# Epoch 20 --> loss = 0.008889195006330555
# Epoch 19: model accuracy 97.53%
# Epoch 1 --> loss = 0.5482312543972977
# Epoch 0: model accuracy 92.60%
# Epoch 2 --> loss = 0.21026343715263965
# Epoch 1: model accuracy 95.19%
# Epoch 3 --> loss = 0.15056142444684625
# Epoch 2: model accuracy 95.80%
# Epoch 4 --> loss = 0.11920718025606769
# Epoch 3: model accuracy 96.12%
# Epoch 5 --> loss = 0.0973831609870468
# Epoch 4: model accuracy 97.00%
# Epoch 6 --> loss = 0.0821491082214804
# Epoch 5: model accuracy 96.42%
# Epoch 7 --> loss = 0.07222727143308962
# Epoch 6: model accuracy 97.10%
# Epoch 8 --> loss = 0.06295728555861622
# Epoch 7: model accuracy 97.32%
# Epoch 9 --> loss = 0.05518186950697693
# Epoch 8: model accuracy 97.36%
# Epoch 10 --> loss = 0.049571812656005104
# Epoch 9: model accuracy 97.33%
# Epoch 11 --> loss = 0.04462126334324908
# Epoch 10: model accuracy 95.87%
# Epoch 12 --> loss = 0.0407242036675528
# Epoch 11: model accuracy 97.68%
# Epoch 13 --> loss = 0.035623058429616355
# Epoch 12: model accuracy 97.25%
# Epoch 14 --> loss = 0.031862661494056324
# Epoch 13: model accuracy 95.94%
# Epoch 15 --> loss = 0.02886329819947215
# Epoch 14: model accuracy 97.54%
# Epoch 16 --> loss = 0.025261517305153983
# Epoch 15: model accuracy 97.41%
# Epoch 17 --> loss = 0.02296729475863701
# Epoch 16: model accuracy 97.52%
# Epoch 18 --> loss = 0.021148169842071587
# Epoch 17: model accuracy 97.72%
# Epoch 19 --> loss = 0.018487335501193032
# Epoch 18: model accuracy 97.50%
# Epoch 20 --> loss = 0.016285983541118317
# Epoch 19: model accuracy 97.54%
# Epoch 1 --> loss = 0.7159724914188832
# Epoch 0: model accuracy 90.67%
# Epoch 2 --> loss = 0.2878649694515444
# Epoch 1: model accuracy 93.10%
# Epoch 3 --> loss = 0.2218271796859658
# Epoch 2: model accuracy 94.53%
# Epoch 4 --> loss = 0.18059558208499635
# Epoch 3: model accuracy 95.25%
# Epoch 5 --> loss = 0.1517616184805629
# Epoch 4: model accuracy 95.84%
# Epoch 6 --> loss = 0.13085336364440317
# Epoch 5: model accuracy 96.19%
# Epoch 7 --> loss = 0.11464491961543748
# Epoch 6: model accuracy 96.27%
# Epoch 8 --> loss = 0.10071840271877963
# Epoch 7: model accuracy 96.67%
# Epoch 9 --> loss = 0.09117002442066095
# Epoch 8: model accuracy 96.40%
# Epoch 10 --> loss = 0.08182237477603752
# Epoch 9: model accuracy 97.03%
# Epoch 11 --> loss = 0.07463401067716036
# Epoch 10: model accuracy 97.19%
# Epoch 12 --> loss = 0.06854422515762576
# Epoch 11: model accuracy 97.18%
# Epoch 13 --> loss = 0.06304131721708375
# Epoch 12: model accuracy 97.36%
# Epoch 14 --> loss = 0.05882645974050898
# Epoch 13: model accuracy 97.19%
# Epoch 15 --> loss = 0.053925083358404735
# Epoch 14: model accuracy 97.09%
# Epoch 16 --> loss = 0.05066135746520211
# Epoch 15: model accuracy 97.36%
# Epoch 17 --> loss = 0.0468914007215993
# Epoch 16: model accuracy 97.46%
# Epoch 18 --> loss = 0.04383185796979775
# Epoch 17: model accuracy 97.49%
# Epoch 19 --> loss = 0.040683044548601166
# Epoch 18: model accuracy 97.49%
# Epoch 20 --> loss = 0.03755238274686229
# Epoch 19: model accuracy 97.32%
# Best Accuracy: 0.972
# Best Hyperparameters: {'learning_rate': 0.001, 'num_epochs': 5, 'hidden_layers': [128, 64], 'batch_size': 32}
